# %%
[Link to Matplotlib Test](#Matplotlib-Test)

[Link to Other Test](#Other-Test)

# %% [markdown]
# #Matplotlib Test

# %%
import numpy as np
import matplotlib.pyplot as plt
# %autosave 0
# Out:
# Autosave disabled

# %%
x = np.random.randn(10000)

# %%
# %matplotlib inline

# %%
plt.hist(x, 20)
plt.title('This is just a test')
plt.ylabel('some numbers')
plt.xlabel('some bins')
plt.text(-4, 1400, r'$\mu=0,\ \sigma=2$', fontsize=16, color='blue')
plt.show()

# %% [markdown]
# ##Working with Multiple Subplots

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1,2,3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4,5,6])

plt.figure(2)                # a second figure
plt.plot([4,5,6])            # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1,2,3')   # subplot 211 title

# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# #Other Test

# %%
Linking notebooks

Heading cells automatically get anchors with their text, so you can link to them:

[like this](#Autosave)

like this

You can also link to headings in other notebooks:

[The EuroSciPy notebook](EuroSciPy.ipynb#The-Team)

The EuroSciPy notebook

Note that for HTML / HTTP reasons, spaces in the notebook filename should be replaced with %20, and spaces in heading anchors should be replaced with -.

# %%
fig,ax = plt.subplots(3,2)

# %%
ax
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x108d89590>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x109838710>]], dtype=object)

# %%
ax[0]
plot([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2acb6814639d> in <module>()
#       1 ax[0]
# ----> 2 plot([1,2,3])
#
# NameError: name 'plot' is not defined
