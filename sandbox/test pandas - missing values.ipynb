# %%
import numpy as np
import pandas as pd
from numpy import NaN
from addutils import side_by_side2
from addutils import css_notebook
from addutils import read_txt
from faker import Factory
from IPython.core.display import HTML
css_notebook()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:900px;
#         margin-left:0% !important;
#         margin-right:0%;
#     }
#
# 	code{
# 		font-size:10pt
# 	}
#
#     h1 {
#         font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:28pt;
#     }
# 	h2 {
#         font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:24pt;
#     }
# 	h3 {
#         font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:20pt;
#     }
#     h4 {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:18pt;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#
# 	ul {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 90, 90, 90 );
# 		font-size:11pt;
# 		line-height: 185%;
# 		}
#
# 	p {
# 		font-family: Tahoma, sans-serif;
# ...

# %%
df = pd.DataFrame(np.random.randint(0, 9, (4,5)), columns=list('ABCDE'))
df.ix[1,1:3] = np.nan
df.ix[2,2:4] = np.nan
df
# Out:
#    A   B   C   D  E
# 0  6   1   4   6  7
# 1  4 NaN NaN   8  3
# 2  4   1 NaN NaN  3
# 3  5   8   8   1  6
#
# [4 rows x 5 columns]

# %%
df.fillna(value=88)
# Out:
#    A   B   C   D  E
# 0  6   1   4   6  7
# 1  4  88  88   8  3
# 2  4   1  88  88  3
# 3  5   8   8   1  6
#
# [4 rows x 5 columns]

# %%
HTML(side_by_side2(df.fillna(method='backfill'), df.fillna(method='backfill', axis=1)))
# Out:
# <div style="float:left;padding-right: 0.6em;max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> 6</td>
#       <td> 1</td>
#       <td> 4</td>
#       <td> 6</td>
#       <td> 7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> 4</td>
#       <td> 1</td>
#       <td> 8</td>
#       <td> 8</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> 4</td>
#       <td> 1</td>
#       <td> 8</td>
#       <td> 1</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> 5</td>
#       <td> 8</td>
#       <td> 8</td>
#       <td> 1</td>
#       <td> 6</td>
#     </tr>
#   </tbody>
# </table>
# <p>4 rows × 5 columns</p>
# ...

# %%
HTML(side_by_side2(df, df.dropna(), df.dropna(axis=1)))
# Out:
# <div style="float:left;padding-right: 0.6em;max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> 6</td>
#       <td>  1</td>
#       <td>  4</td>
#       <td>  6</td>
#       <td> 7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> 4</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>  8</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> 4</td>
#       <td>  1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> 5</td>
#       <td>  8</td>
#       <td>  8</td>
#       <td>  1</td>
#       <td> 6</td>
#     </tr>
#   </tbody>
# </table>
# <p>4 rows × 5 columns</p>
# ...
