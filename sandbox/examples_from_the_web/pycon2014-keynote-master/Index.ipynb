# %% [markdown]
# <p class="talk-title">Python & Science</p>
#
# <p class="talk-subtitle">How OSS and Python are transforming science</p>
#
# <center>
#
# <p class="gap05"<p>
# <h3> Fernando Pérez </h3>
# <h3>[fperez.org](http://fperez.org), [@fperez_org](http://twitter.com/fperez_org)</h3>
# <h3>UC Berkeley</h3>
#
# <p class="gap05"<p>
# <h2>[ipython.org](http://ipython.org)</h2>
#
#
# <p class="gap2"<p>
# </center>

# %%
# %pylab inline
# %run talktools
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>
# /*
#    Simple CSS styling for using IPython Notebooks for talks.
#
#    Author: Fernando Perez <fernando.perez@berkeley.edu>
# */
#
# .talk-title
# {
#   color: #498AF3;
#   font-size: 220%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 10px 50px 10px;
#   }
#
# .talk-subtitle
# {
#   color: #386BBC;
#   font-size: 150%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   }
#
# .slide-header, p.slide-header
# {
#   color: #498AF3;
#   font-size: 180%;
#   font-weight:bold;
#   margin: 0px 20px 10px;
#   page-break-before: always;
#   text-align: center;
#   }
#
# .rendered_html
# {
#   color: #2C5494;
#   font-family: Ubuntu;
#   font-size: 170%;
#   line-height: 1.1;
#   margin: 0.5em 0;
#   }
#
# .rendered_html h1
# {
#   color: #498AF3;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .rendered_html h2
# ...

# %% [markdown]
# # Talk outline
#
# * [Open Source - Open Science](Open Source - Open Science.ipynb)
# * [IPython: the core project](IPython.ipynb)
# * [The IPython Notebook ecosystem](Notebook Ecosystem.ipynb)
