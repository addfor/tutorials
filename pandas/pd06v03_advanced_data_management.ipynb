# %% [markdown]
# # Split apply and combine

# %%
import addutils.toc ; addutils.toc.js(ipy_notebook=True)
# Out:
# <div id='toc-container' ?><script type='text/javascript'>
# $(function() {
#     function regenTOC(){
#         if (typeof element === 'undefined') {
#                 element = $("#toc-container");
#         } else {
#                 var container = document.createElement("div");
#                 $(container).attr('id', 'toc-container');
#                 $(element).empty().append(element);
#                 element = container;
#         }
#
# 	var toc = document.createElement("div");
# 	$(toc).attr("class", "table-of-contents");
#
# 	var curLevel = 0;
# 	var containerStack = [toc];
# 	var levelOfTag = {"h2": 1, "h3": 2, "h4": 3, "h5": 4};
#
# 	function pushLevel() {
#             var list = document.createElement("ul");
#             containerStack.push(list);
#             curLevel++;
# 	}
#
# 	function popLevel() {
#             var lastContainer = containerStack.pop();
#             $(lastContainer).appendTo(containerStack[containerStack.length - 1]);
#             curLevel--;
# 	}
#
# 	$(".text_cell_render :header").each(function (i, elem) {
#             var level = levelOfTag[ elem.tagName.toLowerCase() ];
#
#             if (level === undefined)
# 		return;
#
#             while (curLevel < level)
# 		pushLevel();
#             while (curLevel > level)
# 		popLevel();
#
#             var listItem = document.createElement("li");
#             var link = document.createElement("a");
#             $(link)
# 		.text($(elem).contents().first().text()) // Remove the pilcrow sign
# 		.attr("href", "#" + $(elem).attr("id"))
# 		.appendTo(listItem);
#             $(listItem).appendTo(containerStack[containerStack.length - 1]);
# 	});
#
# 	while (curLevel > 0)
#             popLevel();
#
#         $("<a class='btn-update' href='#'>Update</a>")
#           .click(regenTOC).prependTo(toc);
#
# 	$(toc).prepend("<div class='title'>Contents</div>")
#           .wrap("<div class='toc-headings'/>");
#
#         $(element).empty();
#         $(element).append(toc);
#     }
#
#     if (typeof IPython !== 'undefined')
#         $([IPython.events]).on('notebook_loaded.Notebook', regenTOC);
#     regenTOC();
# });
#
# </script>

# %%
from utilities.generators import generate_all
generate_all()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b41ca877d0b5> in <module>()
# ----> 1 from utilities.generators import generate_all
#       2 generate_all()
#
# ImportError: No module named utilities.generators

# %% [markdown]
# In this tutorial we are going to see advanced data management with `pandas` data structures.

# %%
import numpy as np
import pandas as pd
from pandas.io.data import DataFrame, read_csv
from IPython.display import (display, HTML)
from addutils import side_by_side2
from addutils import css_notebook
css_notebook()
# Out:
# <style>
# .text_cell_render @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# div.cell {
#     width: 900px;
#     margin-left: 0% !important;
#     margin-right: 0%;
# }
#
# code {
#     font-size:10pt;
# }
#
# .text_cell_render  h1 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:28pt;
# }
# .text_cell_render h2 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:24pt;
# }
# .text_cell_render h3 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:20pt;
# }
# .text_cell_render h4 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:18pt;
#     margin-top:12px;
#     margin-bottom: 3px;
# }
#
# .text_cell_render h5 {
#     font-weight: 300;
#     font-size: 11pt;
#     color: rgb( 48, 48, 48 );
#     font-style: italic;
#     margin-bottom: .5em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render ul {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
#     line-height: 185%;
# }
#
# .text_cell_render yp {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
# }
#
# .text_cell_render strong {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 30, 30, 30 );
#     font-size:11pt;
# }
#
# .text_cell_render a:link {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:11pt;
# }
#
# .text_cell_render a:visited {
#     color:rgb( 10, 88, 126 );
# }
#
# .text_cell_render {
#     font-family: Helvetica, Courier, Computer Modern, "Helvetica Neue", Arial, Geneva, sans-serif;
#     color: rgb( 84, 84, 84 );
#     font-size:11pt;
#     line-height: 125%;
#     font-size: 100%;
#     width:800px;
# }
#
# .CodeMirror {
#     font-family: Courier, "Source Code Pro", source-code-pro,Consolas, monospace;
# }
#
# .warning {
#     color: rgb( 240, 20, 20 );
# }
#
# /* Pandas tables */
# /*
# .rendered_html td {
#     text-align: right;
# }
# */
#
# table.dataframe td {
#     text-align: right;
# }
#
# .output .table-of-contents {
#     border: 1px #cecece solid;
#     background-color: #fafafa;
#     padding-top: 10px;
#     padding-bottom: 5px;
#     padding-right: 15px;
#     padding-left: 0px;
#     margin-bottom: 20px;
#     display: inline-block;
#     position: relative;
# }
#
# .output .table-of-contents ul {
#     list-style-type: none;
#     padding-left: 20px;
# }
#
# .output .table-of-contents .title {
#     font-weight: bold;
#     font-height: 11pt;
#     padding-left: 20px; /* looks better if it's the same to the <ul> */
# }
#
# .output .table-of-contents .btn-update {
#     position: absolute;
#     float: right;
#     right: 11px;
#     top: 4px;
#     font-size: 9pt;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# Categorizing a data set and applying a function to each group, is often a critical component of a data analysis workflow. After
# loading, merging, and preparing a data set, a familiar task is to compute group statistics or possibly pivot tables for reporting or visualization purposes. *pandas* provides a flexible and high-performance groupby facility.
#
# By *'group by'* we refer to a process involving one or more of the following steps:
#
# * **Splitting** the data into groups based on some criteria
# * **Applying** a function to each group independently
# * **Combining** the results into a data structure
#
# Suppose we are managing a website and we have a log-file with number of *wiews* and *likes* coming from different cities:

# %%
d1 = read_csv('temp/p07_d1.txt', index_col=0)
d1 = d1.reindex(columns=['State','City','Views','Likes'])
display(d1)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-9682fa2522ad> in <module>()
# ----> 1 d1 = read_csv('temp/p07_d1.txt', index_col=0)
#       2 d1 = d1.reindex(columns=['State','City','Views','Likes'])
#       3 display(d1)
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1059         kwds['allow_leading_cols'] = self.index_col is not False
#    1060
# -> 1061         self._reader = _parser.TextReader(src, **kwds)
#    1062
#    1063         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3150)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5772)()
#
# IOError: File temp/p07_d1.txt does not exist

# %% [markdown]
# ## 1 Groupby

# %% [markdown]
# `groupby` groups DataFrame or Series by a parameter on a given axis:

# %%
g1 = d1.groupby('State')
print g1.groups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-76dd36fc9076> in <module>()
# ----> 1 g1 = d1.groupby('State')
#       2 print g1.groups
#
# NameError: name 'd1' is not defined

# %% [markdown]
# The variable `groups` of a `GroupBy` object is a dictionary containing indexes of each group member.

# %%
for name,group in g1:
    print name
    print group
    print 'Total Views: %d - Total Likes: %d\n\n' %(group['Views'].sum(),
                                                    group['Likes'].sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f5eb6e61e997> in <module>()
# ----> 1 for name,group in g1:
#       2     print name
#       3     print group
#       4     print 'Total Views: %d - Total Likes: %d\n\n' %(group['Views'].sum(),
#       5                                                     group['Likes'].sum())
#
# NameError: name 'g1' is not defined

# %% [markdown]
# It is also possibile to apply a `groupby` over a hierarchical index `DataFrame`

# %%
d2 = d1.set_index(['State','City'])
display(d2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-114f0ba12099> in <module>()
# ----> 1 d2 = d1.set_index(['State','City'])
#       2 display(d2)
#
# NameError: name 'd1' is not defined

# %% [markdown]
# ## 2 Aggregate

# %% [markdown]
# Once the GroupBy object has been created, several methods are available to perform a computation on the grouped data. Here we use `aggregate`. The result of the aggregation will have the group names as the new index along the grouped axis. In the case of multiple keys, the result is a MultiIndex by default, though this can be changed by using the `as_index option`:

# %%
g2 = d2.groupby(level=[0])
print g2.groups
g2.aggregate(np.sum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aa485dcaf804> in <module>()
# ----> 1 g2 = d2.groupby(level=[0])
#       2 print g2.groups
#       3 g2.aggregate(np.sum)
#
# NameError: name 'd2' is not defined

# %%
g3 = d2.groupby(level=[0,1])
g4 = d2.groupby(level=[0,1], as_index=False)
HTML(side_by_side2(g3.aggregate(np.sum), g4.aggregate(np.sum)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-70e026542a3e> in <module>()
# ----> 1 g3 = d2.groupby(level=[0,1])
#       2 g4 = d2.groupby(level=[0,1], as_index=False)
#       3 HTML(side_by_side2(g3.aggregate(np.sum), g4.aggregate(np.sum)))
#
# NameError: name 'd2' is not defined

# %% [markdown]
# `aggregate` allows to pass any function that returns a scalar value from a vector and can handle list of functions:

# %%
d1[['State', 'Views']].groupby('State').aggregate([np.sum, np.mean, np.std])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-398f0d95295c> in <module>()
# ----> 1 d1[['State', 'Views']].groupby('State').aggregate([np.sum, np.mean, np.std])
#
# NameError: name 'd1' is not defined

# %% [markdown]
# ## 3 Apply

# %% [markdown]
# `apply` will extend the previous concepts to any Python function:

# %%
pd.set_option('display.float_format', lambda x: '{:.1f}'.format(x))

def add_field(group):
    group['Tot.Views'] = group['Views'].sum()
    group['Likes[%]'] = 100.0*group['Likes']/group['Likes'].sum()
    return group

HTML(side_by_side2(d1, d1.groupby('State').apply(add_field)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1b0c2eadf978> in <module>()
#       6     return group
#       7
# ----> 8 HTML(side_by_side2(d1, d1.groupby('State').apply(add_field)))
#
# NameError: name 'd1' is not defined

# %% [markdown]
# ## 4 A pratical example: Normalize by year

# %%
idx = pd.date_range('1999/5/28', periods=1500, freq='1B')
s1 = pd.Series(np.random.normal(5.5, 2, 1500), idx)
s1 = pd.rolling_mean(s1, 10, 10).dropna()

# %% [markdown]
# Here we define a grouping key for months and one for years:

# %%
def my_groupby_key_year(timestamp):
    return timestamp.year

def my_groupby_key_month(timestamp):
    return timestamp.month

def my_normalization(group):
    return (group-group.mean())/group.std()

# %% [markdown]
# Here we normalize the data on a monthly base and check mean and std on an yearly base:

# %%
t1 = s1.groupby(my_groupby_key_month).apply(my_normalization)

HTML(side_by_side2(s1.head(8),
                   t1.head(8),
                   t1.groupby(my_groupby_key_year).aggregate([np.mean, np.std])))
# Out:
# <div style="float:left;padding-right: 0.6em;max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1999-06-10</th>
#       <td>4.6</td>
#     </tr>
#     <tr>
#       <th>1999-06-11</th>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>1999-06-14</th>
#       <td>4.5</td>
#     </tr>
#     <tr>
#       <th>1999-06-15</th>
#       <td>4.3</td>
#     </tr>
#     <tr>
#       <th>1999-06-16</th>
#       <td>4.2</td>
#     </tr>
#     <tr>
#       <th>1999-06-17</th>
#       <td>4.2</td>
#     </tr>
#     <tr>
#       <th>1999-06-18</th>
#       <td>4.3</td>
#     </tr>
#     <tr>
#       <th>1999-06-21</th>
#       <td>4.6</td>
#     </tr>
#   </tbody>
# </table>
# </div><div style="float:left;padding-right: 0.6em;max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1999-06-10</th>
#       <td>-1.3</td>
#     </tr>
#     <tr>
#       <th>1999-06-11</th>
#       <td>-1.6</td>
#     </tr>
#     <tr>
#       <th>1999-06-14</th>
#       <td>-1.4</td>
#     </tr>
#     <tr>
#       <th>1999-06-15</th>
#       <td>-1.8</td>
#     </tr>
#     <tr>
#       <th>1999-06-16</th>
#       <td>-1.9</td>
#     </tr>
#     <tr>
#       <th>1999-06-17</th>
#       <td>-1.9</td>
#     </tr>
#     <tr>
#       <th>1999-06-18</th>
#       <td>-1.8</td>
#     </tr>
#     <tr>
#       <th>1999-06-21</th>
#       <td>-1.3</td>
#     </tr>
#   </tbody>
# </table>
# </div><div style="float:left;padding-right: 0.6em;max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mean</th>
#       <th>std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1999</th>
#       <td> 0.1</td>
#       <td>1.1</td>
#     </tr>
#     <tr>
#       <th>2000</th>
#       <td> 0.1</td>
#       <td>0.9</td>
#     </tr>
#     <tr>
#       <th>2001</th>
#       <td> 0.2</td>
#       <td>1.1</td>
#     </tr>
#     <tr>
#       <th>2002</th>
#       <td>-0.1</td>
#       <td>0.9</td>
#     </tr>
#     <tr>
#       <th>2003</th>
#       <td> 0.0</td>
#       <td>0.9</td>
#     </tr>
#     <tr>
#       <th>2004</th>
#       <td>-0.1</td>
#       <td>0.9</td>
#     </tr>
#     <tr>
#       <th>2005</th>
#       <td>-0.2</td>
#       <td>1.3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 5 A practical example: Group and standardize by dimension

# %%
d3 = pd.read_csv('example_data/company.csv', index_col=0)
display(d3.head())
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-15-6eaa8ca2c443> in <module>()
# ----> 1 d3 = pd.read_csv('example_data/company.csv', index_col=0)
#       2 display(d3.head())
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1059         kwds['allow_leading_cols'] = self.index_col is not False
#    1060
# -> 1061         self._reader = _parser.TextReader(src, **kwds)
#    1062
#    1063         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3150)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5772)()
#
# IOError: File example_data/company.csv does not exist

# %% [markdown]
# Since the column "Value" is made by strings with a space separator we need a simpel intermediate step to convert values from string to floats:

# %%
d3['Value'] = d3['Value'].apply(lambda x: float(x.replace(' ', '')))
d3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3c451c792040> in <module>()
# ----> 1 d3['Value'] = d3['Value'].apply(lambda x: float(x.replace(' ', '')))
#       2 d3.head()
#
# NameError: name 'd3' is not defined

# %%
d3.groupby('Dimension').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6f7a04ce813a> in <module>()
# ----> 1 d3.groupby('Dimension').mean()
#
# NameError: name 'd3' is not defined

# %% [markdown]
# ---
#
# Visit [www.add-for.com](<http://www.add-for.com/IT>) for more tutorials and updates
# This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
