# %% [markdown]
# # pandas I/O tools and examples

# %%
import addutils.toc ; addutils.toc.js(ipy_notebook=True)
# Out:
# <div id='toc-container' ?><script type='text/javascript'>
# $(function() {
#     function regenTOC(){
#         if (typeof element === 'undefined') {
#                 element = $("#toc-container");
#         } else {
#                 var container = document.createElement("div");
#                 $(container).attr('id', 'toc-container');
#                 $(element).empty().append(element);
#                 element = container;
#         }
#
# 	var toc = document.createElement("div");
# 	$(toc).attr("class", "table-of-contents");
#
# 	var curLevel = 0;
# 	var containerStack = [toc];
# 	var levelOfTag = {"h2": 1, "h3": 2, "h4": 3, "h5": 4};
#
# 	function pushLevel() {
#             var list = document.createElement("ul");
#             containerStack.push(list);
#             curLevel++;
# 	}
#
# 	function popLevel() {
#             var lastContainer = containerStack.pop();
#             $(lastContainer).appendTo(containerStack[containerStack.length - 1]);
#             curLevel--;
# 	}
#
# 	$(".text_cell_render :header").each(function (i, elem) {
#             var level = levelOfTag[ elem.tagName.toLowerCase() ];
#
#             if (level === undefined)
# 		return;
#
#             while (curLevel < level)
# 		pushLevel();
#             while (curLevel > level)
# 		popLevel();
#
#             var listItem = document.createElement("li");
#             var link = document.createElement("a");
#             $(link)
# 		.text($(elem).contents().first().text()) // Remove the pilcrow sign
# 		.attr("href", "#" + $(elem).attr("id"))
# 		.appendTo(listItem);
#             $(listItem).appendTo(containerStack[containerStack.length - 1]);
# 	});
#
# 	while (curLevel > 0)
#             popLevel();
#
#         $("<a class='btn-update' href='#'>Update</a>")
#           .click(regenTOC).prependTo(toc);
#
# 	$(toc).prepend("<div class='title'>Contents</div>")
#           .wrap("<div class='toc-headings'/>");
#
#         $(element).empty();
#         $(element).append(toc);
#     }
#
#     if (typeof IPython !== 'undefined')
#         $([IPython.events]).on('notebook_loaded.Notebook', regenTOC);
#     regenTOC();
# });
#
# </script>

# %% [markdown]
# ## 1 Matlab Variables

# %% [markdown]
# ### 1.1 Import a Matlab variable from file

# %%
import re
import os 
import scipy.io
import numpy as np
import pandas as pd
import sqlite3
from pandas.io.data import DataFrame, read_csv
import pandas.io.sql as psql
from time import time
from IPython.display import display
from addutils import css_notebook
css_notebook()
# Out:
# <style>
# .text_cell_render @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# div.cell {
#     width: 900px;
#     margin-left: 0% !important;
#     margin-right: 0%;
# }
#
# code {
#     font-size:10pt;
# }
#
# .text_cell_render  h1 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:28pt;
# }
# .text_cell_render h2 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:24pt;
# }
# .text_cell_render h3 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:20pt;
# }
# .text_cell_render h4 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:18pt;
#     margin-top:12px;
#     margin-bottom: 3px;
# }
#
# .text_cell_render h5 {
#     font-weight: 300;
#     font-size: 11pt;
#     color: rgb( 48, 48, 48 );
#     font-style: italic;
#     margin-bottom: .5em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render ul {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
#     line-height: 185%;
# }
#
# .text_cell_render yp {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
# }
#
# .text_cell_render strong {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 30, 30, 30 );
#     font-size:11pt;
# }
#
# .text_cell_render a:link {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:11pt;
# }
#
# .text_cell_render a:visited {
#     color:rgb( 10, 88, 126 );
# }
#
# .text_cell_render {
#     font-family: Helvetica, Courier, Computer Modern, "Helvetica Neue", Arial, Geneva, sans-serif;
#     color: rgb( 84, 84, 84 );
#     font-size:11pt;
#     line-height: 125%;
#     font-size: 100%;
#     width:800px;
# }
#
# .CodeMirror {
#     font-family: Courier, "Source Code Pro", source-code-pro,Consolas, monospace;
# }
#
# .warning {
#     color: rgb( 240, 20, 20 );
# }
#
# /* Pandas tables */
# /*
# .rendered_html td {
#     text-align: right;
# }
# */
#
# table.dataframe td {
#     text-align: right;
# }
#
# .output .table-of-contents {
#     border: 1px #cecece solid;
#     background-color: #fafafa;
#     padding-top: 10px;
#     padding-bottom: 5px;
#     padding-right: 15px;
#     padding-left: 0px;
#     margin-bottom: 20px;
#     display: inline-block;
#     position: relative;
# }
#
# .output .table-of-contents ul {
#     list-style-type: none;
#     padding-left: 20px;
# }
#
# .output .table-of-contents .title {
#     font-weight: bold;
#     font-height: 11pt;
#     padding-left: 20px; /* looks better if it's the same to the <ul> */
# }
#
# .output .table-of-contents .btn-update {
#     position: absolute;
#     float: right;
#     right: 11px;
#     top: 4px;
#     font-size: 9pt;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %% [markdown]
# Import from '.mat' files

# %%
x = scipy.io.loadmat('example_data/matlab_variable.mat')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-28f4684152c5> in <module>()
# ----> 1 x = scipy.io.loadmat('example_data/matlab_variable.mat')
#
# /opt/anaconda/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in loadmat(file_name, mdict, appendmat, **kwargs)
#     132     """
#     133     variable_names = kwargs.pop('variable_names', None)
# --> 134     MR = mat_reader_factory(file_name, appendmat, **kwargs)
#     135     matfile_dict = MR.get_variables(variable_names)
#     136     if mdict is not None:
#
# /opt/anaconda/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in mat_reader_factory(file_name, appendmat, **kwargs)
#      55        type detected in `filename`.
#      56     """
# ---> 57     byte_stream = _open_file(file_name, appendmat)
#      58     mjv, mnv = get_matfile_version(byte_stream)
#      59     if mjv == 0:
#
# /opt/anaconda/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in _open_file(file_like, appendmat)
#      21     if isinstance(file_like, string_types):
#      22         try:
# ---> 23             return open(file_like, 'rb')
#      24         except IOError as e:
#      25             if appendmat and not file_like.endswith('.mat'):
#
# IOError: [Errno 2] No such file or directory: 'example_data/matlab_variable.mat'

# %%
pyA = x['a']
pyA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9ad5b9b28a02> in <module>()
# ----> 1 pyA = x['a']
#       2 pyA
#
# NameError: name 'x' is not defined

# %% [markdown]
# The Matlab variable is passed to a pandas DataFrame:

# %%
df = pd.DataFrame(pyA)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cea4dc5fef4a> in <module>()
# ----> 1 df = pd.DataFrame(pyA)
#       2 df
#
# NameError: name 'pyA' is not defined

# %% [markdown]
# ## 2 Importing a compressed CSV

# %% [markdown]
# The following example shows how to import directly a compressed csv file, in this case with multiple separators:

# %%
df_csv = pd.read_csv('example_data/pd12_peopl.csv.gz', sep=r'\,\;\.',
                     skipinitialspace=True, compression='gzip')
df_csv.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-c36dff185e04> in <module>()
#       1 df_csv = pd.read_csv('example_data/pd12_peopl.csv.gz', sep=r'\,\;\.',
# ----> 2                      skipinitialspace=True, compression='gzip')
#       3 df_csv.head()
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     698             elif engine == 'python-fwf':
#     699                 klass = FixedWidthFieldParser
# --> 700             self._engine = klass(self.f, **self.options)
#     701
#     702     def _failover_to_python(self):
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, **kwds)
#    1384         if isinstance(f, compat.string_types):
#    1385             f = com._get_handle(f, 'r', encoding=self.encoding,
# -> 1386                                 compression=self.compression)
#    1387         elif self.compression:
#    1388             f = _wrap_compressed(f, self.compression, self.encoding)
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/core/common.pyc in _get_handle(path, mode, encoding, compression)
#    2691         if compression == 'gzip':
#    2692             import gzip
# -> 2693             f = gzip.GzipFile(path, 'rb')
#    2694         elif compression == 'bz2':
#    2695             import bz2
#
# /opt/anaconda/lib/python2.7/gzip.pyc in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#      92             mode += 'b'
#      93         if fileobj is None:
# ---> 94             fileobj = self.myfileobj = __builtin__.open(filename, mode or 'rb')
#      95         if filename is None:
#      96             # Issue #13781: os.fdopen() creates a fileobj with a bogus name
#
# IOError: [Errno 2] No such file or directory: 'example_data/pd12_peopl.csv.gz'

# %%
coor = df_csv['Coordinates']
df_csv['lat'] = ''
df_csv['lon'] = ''
for j, coo in enumerate(coor):
    spl = re.split(',', str(coo))
    df_csv['lat'][j] = spl[0]
    df_csv['lon'][j] = spl[1]
df_csv.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3683f95f828b> in <module>()
# ----> 1 coor = df_csv['Coordinates']
#       2 df_csv['lat'] = ''
#       3 df_csv['lon'] = ''
#       4 for j, coo in enumerate(coor):
#       5     spl = re.split(',', str(coo))
#
# NameError: name 'df_csv' is not defined

# %%
df_csv.to_json('converted_json.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-86c627c04756> in <module>()
# ----> 1 df_csv.to_json('converted_json.json')
#
# NameError: name 'df_csv' is not defined

# %% [markdown]
# ## 3 Importing JSON files

# %%
#dfjson = pd.read_json(fg.get_example('generatedSimple.json'))
dfjson = pd.read_json('converted_json.json')
dfjson.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d585c8dc3c01> in <module>()
#       1 #dfjson = pd.read_json(fg.get_example('generatedSimple.json'))
# ----> 2 dfjson = pd.read_json('converted_json.json')
#       3 dfjson.head()
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     196         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     197                           keep_default_dates, numpy, precise_float,
# --> 198                           date_unit).parse()
#     199
#     200     if typ == 'series' or obj is None:
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in parse(self)
#     264
#     265         else:
# --> 266             self._parse_no_numpy()
#     267
#     268         if self.obj is None:
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in _parse_no_numpy(self)
#     481         if orient == "columns":
#     482             self.obj = DataFrame(
# --> 483                 loads(json, precise_float=self.precise_float), dtype=None)
#     484         elif orient == "split":
#     485             decoded = dict((str(k), v)
#
# ValueError: Expected object or value

# %% [markdown]
# Since the import reordered columns in alphabetical order, we can choose a preferred column order:

# %%
dfjson = dfjson.ix[:, ['ID', 'Names', 'Phone', 'Income', 'Town', 'lat', 'lon']]
dfjson.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-302a8e94de7e> in <module>()
# ----> 1 dfjson = dfjson.ix[:, ['ID', 'Names', 'Phone', 'Income', 'Town', 'lat', 'lon']]
#       2 dfjson.head()
#
# NameError: name 'dfjson' is not defined

# %% [markdown]
# ## 4 Importing HTML

# %% [markdown]
# Note: `read_html` returns a **list** of DataFrame objects, even if there is only a single table contained in the `HTML` content. Infer_types avoids the function trying to automatically detect numeric and date types (this generated an error with coordinates)

# %%
dfhtml = pd.read_html('example_data/generated.html', header=0)
dfhtml[0].head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-782db95d981a> in <module>()
# ----> 1 dfhtml = pd.read_html('example_data/generated.html', header=0)
#       2 dfhtml[0].head()
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, infer_types, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     849                          'data (you passed a negative value)')
#     850     return _parse(flavor, io, match, header, index_col, skiprows, infer_types,
# --> 851                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, infer_types, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     703     retained = None
#     704     for flav in flavor:
# --> 705         parser = _parser_dispatch(flav)
#     706         p = parser(io, compiled_match, attrs, encoding)
#     707
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in _parser_dispatch(flavor)
#     649     if flavor in ('bs4', 'html5lib'):
#     650         if not _HAS_HTML5LIB:
# --> 651             raise ImportError("html5lib not found, please install it")
#     652         if not _HAS_BS4:
#     653             raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %% [markdown]
# ## 5 Importing Excel

# %%
dfxl = pd.read_excel('example_data/generated2.xls', 'foglio')
dfxl.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-13-12be856b071a> in <module>()
# ----> 1 dfxl = pd.read_excel('example_data/generated2.xls', 'foglio')
#       2 dfxl.head()
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheetname, **kwds)
#     130     engine = kwds.pop('engine', None)
#     131
# --> 132     return ExcelFile(io, engine=engine).parse(sheetname=sheetname, **kwds)
#     133
#     134
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     167                 self.book = xlrd.open_workbook(file_contents=data)
#     168             else:
# --> 169                 self.book = xlrd.open_workbook(io)
#     170         elif engine == 'xlrd' and isinstance(io, xlrd.Book):
#     171             self.book = io
#
# /opt/anaconda/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     392         peek = file_contents[:peeksz]
#     393     else:
# --> 394         f = open(filename, "rb")
#     395         peek = f.read(peeksz)
#     396         f.close()
#
# IOError: [Errno 2] No such file or directory: 'example_data/generated2.xls'

# %% [markdown]
# ## 6 Working with SQL and databases

# %% [markdown]
# ### 6.1 Write SQL

# %% [markdown]
# Let's store the DataFrame opened from excel in a database. We use SQLite, a database engine library suitable for storing data in a single-file database. 'Names' is the name we chose for the database table we are creating:

# %%
con = sqlite3.connect("temp.sql")
sqlfile = dfxl.to_sql('Names', con, flavor='sqlite')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-87654e0f3b74> in <module>()
#       1 con = sqlite3.connect("temp.sql")
# ----> 2 sqlfile = dfxl.to_sql('Names', con, flavor='sqlite')
#
# NameError: name 'dfxl' is not defined

# %% [markdown]
# ### 6.2 Import SQL

# %%
con = sqlite3.connect('temp.sql')
with con:
    sql = "SELECT * FROM Names;"
    df = psql.frame_query(sql, con)
    print df.shape
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-15-eede9f1dd27d> in <module>()
#       2 with con:
#       3     sql = "SELECT * FROM Names;"
# ----> 4     df = psql.frame_query(sql, con)
#       5     print df.shape
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in frame_query(*args, **kwargs)
#    1568     """
#    1569     warnings.warn("frame_query is deprecated, use read_sql", FutureWarning)
# -> 1570     return read_sql(*args, **kwargs)
#    1571
#    1572
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     466             sql, index_col=index_col, params=params,
#     467             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 468             chunksize=chunksize)
#     469
#     470     try:
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1440
#    1441         args = _convert_params(sql, params)
# -> 1442         cursor = self.execute(*args)
#    1443         columns = [col_desc[0] for col_desc in cursor.description]
#    1444
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1419
#    1420             ex = DatabaseError("Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1421             raise_with_traceback(ex)
#    1422
#    1423     @staticmethod
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1408                 cur.execute(*args, **kwargs)
#    1409             else:
# -> 1410                 cur.execute(*args)
#    1411             return cur
#    1412         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT * FROM Names;': no such table: Names

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
con.close()
os.remove("temp.sql")

# %% [markdown]
# ## 7 Working with HDF5

# %% [markdown]
# ### 7.1 Storer format

# %% [markdown]
# **HDFStore** is a dict-like object used by pandas to store datasets as **HDF5** files using the **PyTables** library. **HDF5** is a scientific hierarchical data format suitable for storing in a file very large and multi-dimensional data arrays. The **Storer** format stores fixed arrays, which are queryiable and must be retrieved in their entirety.

# %% [markdown]
# Add DataFrames to the HDFStore object:

# %%
samples_01 = 3e5
samples_02 = 1e5
idx1 = pd.date_range('1/1/2000 12:00:00', periods=samples_01, freq='50ms', tz='Europe/Rome')
idx2 = pd.date_range('1/1/2000 12:05:00', periods=samples_02, freq='100ms', tz='Europe/Rome')
randn = np.random.randn
df1 = pd.DataFrame(randn(samples_01, 3), index=idx1, columns=['A', 'B', 'C'])
df2 = pd.DataFrame(randn(samples_02, 4), index=idx2, columns=['A', 'B', 'C', 'D'])

# %%
print 'Size of the Dataset: ', (df1.values.nbytes+df1.values.nbytes)/2**20, ' MB'

# %%
# %%timeit
with pd.get_store('store5.h5') as store:
    store.put('storer/df1', df1)
    store.put('storer/df2', df2)
    store.put('to_remove', df2)

# %% [markdown]
# Retrieve stored objects:

# %%
with pd.get_store('store5.h5') as store:
    print store.keys()
    df1_retrieved = store.get('storer/df1')
    print df1_retrieved[1:3]
    print df1[1:3]
    print 'Check retrieved data equal to original data: '
    print df1_retrieved[1:3].equals(df1[1:3])

# %% [markdown]
# Delete objects:

# %%
with pd.get_store('store5.h5') as store:
    try:
        store.remove('to_remove')
    except:
        pass
    print store

# %% [markdown]
# ### 7.2 Table format

# %% [markdown]
# The table format conceptually is shaped very much like a DataFrame and may be appended to in the same or other sessions. In addition, delete & query type operations are supported.

# %%
with pd.get_store('store5.h5') as store:
    # store.append creates a table automatically:
    store.append('table/df1_appended', df1.ix[:10000])

# %%
with pd.get_store('store5.h5') as store:
    store.append('table/df1_appended', df1.ix[10001:20000])
    store.append('table/df1_appended', df1.ix[20001:50000])

# %% [markdown]
# ### 7.3 Querying a Table

# %% [markdown]
# Query the table using boolean expression with in-line function evaluation:

# %%
with pd.get_store('store5.h5') as store:
    query01 = store.select('table/df1_appended',
                           "index>=Timestamp('2000-01-01 12:00:00.20+01:00') \
                           & index<Timestamp('2000-01-01 12:00:00.40+01:00') \
                           & columns=['A', 'B']")
query01
# Out:
#                                          A         B
# 2000-01-01 12:00:00.200000+01:00 -1.101898 -0.315307
# 2000-01-01 12:00:00.250000+01:00  0.320722 -0.566988
# 2000-01-01 12:00:00.300000+01:00  1.555872  0.361491
# 2000-01-01 12:00:00.350000+01:00 -0.977529  0.670213
# 2000-01-01 12:00:00.200000+01:00  1.548555  0.415718
# 2000-01-01 12:00:00.250000+01:00 -1.090527  0.357786
# 2000-01-01 12:00:00.300000+01:00 -0.264072 -0.181619
# 2000-01-01 12:00:00.350000+01:00 -0.227602  1.047986

# %% [markdown]
# ---
#
# Visit [www.add-for.com](<http://www.add-for.com/IT>) for more tutorials and updates.
#
# This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
