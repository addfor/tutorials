# %% [markdown]
# # Linear Models Regularization

# %%
import addutils.toc ; addutils.toc.js(ipy_notebook=True)
# Out:
# <div id='toc-container'><script type='text/javascript'>
# $(function() {
#     function regenTOC(){
#         element = $("#toc-container");
#
# 	var toc = document.createElement("div");
# 	$(toc).attr("class", "table-of-contents");
#
# 	var curLevel = 0;
# 	var containerStack = [toc];
# 	var levelOfTag = {"h2": 1, "h3": 2, "h4": 3, "h5": 4};
#
# 	function pushLevel() {
#             var list = document.createElement("ul");
#             containerStack.push(list);
#             curLevel++;
# 	}
#
# 	function popLevel() {
#             var lastContainer = containerStack.pop();
#             $(lastContainer).appendTo(containerStack[containerStack.length - 1]);
#             curLevel--;
# 	}
#
# 	$(".text_cell_render :header").each(function (i, elem) {
#             var level = levelOfTag[ elem.tagName.toLowerCase() ];
#
#             if (level === undefined)
# 		return;
#
#             while (curLevel < level)
# 		pushLevel();
#             while (curLevel > level)
# 		popLevel();
#
#             var listItem = document.createElement("li");
#             var link = document.createElement("a");
#             $(link)
# 		.text($(elem).contents().first().text()) // Remove the pilcrow sign
# 		.attr("href", "#" + $(elem).attr("id"))
# 		.appendTo(listItem);
#             $(listItem).appendTo(containerStack[containerStack.length - 1]);
# 	});
#
# 	while (curLevel > 0)
#             popLevel();
#
#         $("<a class='btn-update' href='#'>Update</a>")
#           .click(regenTOC).prependTo(toc);
#
# 	$(toc).prepend("<div class='title'>Contents</div>")
#           .wrap("<div class='toc-headings'/>");
#
#         $(element).empty();
#         $(element).append(toc);
#     }
#
#     if (typeof(IPython) !== 'undefined')
#         $([IPython.events]).on('notebook_loaded.Notebook', regenTOC);
#     regenTOC();
# });
#
# </script></div>

# %%
import numpy as np
import pandas as pd
from addutils import css_notebook
from sklearn.datasets.samples_generator import make_regression
from sklearn import linear_model
from sklearn import metrics
css_notebook()
# Out:
# <style>
# .text_cell_render @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# div.cell {
#     width: 900px;
#     margin-left: 0% !important;
#     margin-right: 0%;
# }
#
# code {
#     font-size:10pt;
# }
#
# .text_cell_render  h1 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:28pt;
# }
# .text_cell_render h2 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:24pt;
# }
# .text_cell_render h3 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:20pt;
# }
# .text_cell_render h4 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:18pt;
#     margin-top:12px;
#     margin-bottom: 3px;
# }
#
# .text_cell_render h5 {
#     font-weight: 300;
#     font-size: 11pt;
#     color: rgb( 48, 48, 48 );
#     font-style: italic;
#     margin-bottom: .5em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render ul {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
#     line-height: 185%;
# }
#
# .text_cell_render yp {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
# }
#
# .text_cell_render strong {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 30, 30, 30 );
#     font-size:11pt;
# }
#
# .text_cell_render a:link {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:11pt;
# }
#
# .text_cell_render a:visited {
#     color:rgb( 10, 88, 126 );
# }
#
# .text_cell_render {
#     font-family: Helvetica, Courier, Computer Modern, "Helvetica Neue", Arial, Geneva, sans-serif;
#     color: rgb( 84, 84, 84 );
#     font-size:11pt;
#     line-height: 125%;
#     font-size: 100%;
#     width:800px;
# }
#
# .CodeMirror {
#     font-family: Courier, "Source Code Pro", source-code-pro,Consolas, monospace;
# }
#
# .warning {
#     color: rgb( 240, 20, 20 );
# }
#
# /* Pandas tables */
# /*
# .rendered_html td {
#     text-align: right;
# }
# */
#
# table.dataframe td {
#     text-align: right;
# }
#
# .output .table-of-contents {
#     border: 1px #cecece solid;
#     background-color: #fafafa;
#     padding-top: 10px;
#     padding-bottom: 5px;
#     padding-right: 15px;
#     padding-left: 0px;
#     margin-bottom: 20px;
#     display: inline-block;
#     position: relative;
# }
#
# .output .table-of-contents ul {
#     list-style-type: none;
#     padding-left: 20px;
# }
#
# .output .table-of-contents .title {
#     font-weight: bold;
#     font-height: 11pt;
#     padding-left: 20px; /* looks better if it's the same to the <ul> */
# }
#
# .output .table-of-contents .btn-update {
#     position: absolute;
#     float: right;
#     right: 11px;
#     top: 4px;
#     font-size: 9pt;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import bokeh.plotting as bk
from bokeh import palettes
from bokeh.layouts import gridplot
bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="24a7eb45-7d5a-4eea-bbc7-946c074b8a74">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# We talked about linear models, but we know from real life situations that it is not always the case. How can we transform linear models to be able to cope with nonlinearity?

# %% [markdown]
# ### 1.1 Going beyond linearity

# %% [markdown]
# I have simulated a sine curve (between 60° and 300°) and added some random noise using the following code:

# %%
x = np.array([i*np.pi/180 for i in range(60,300,4)])
np.random.seed(10)  #Setting seed for reproducability
y = np.sin(x) + np.random.normal(0,0.15,len(x))
data = pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])
fig = bk.figure(plot_width=630, plot_height=300, title=None)
fig.circle(data['x'], data['y'],)
bk.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f2d00f22-8d8d-47d3-b9d9-7bd9d21adc46"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f2d00f22-8d8d-47d3-b9d9-7bd9d21adc46").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2d00f22-8d8d-47d3-b9d9-7bd9d21adc46");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2d00f22-8d8d-47d3-b9d9-7bd9d21adc46' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"49b3d2bd-b7bf-479f-9d86-0331a4e3e5f1":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1cdb614b-b299-4d4d-b922-9cae6f33dc8b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"64e12061-60d8-4c69-9c46-7e906f73e5b9","subtype":"Figure","type":"Plot"}},"id":"c2d36b13-d855-420b-acfe-79723d987870","type":"ResetTool"},{"attributes":{"plot":{"id":"64e12061-60d8-4c69-9c46-7e906f73e5b9","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad2e1450-9478-4149-9124-b5d4e8058d7e","type":"BasicTicker"}},"id":"334c04c5-a757-4482-9577-a8b6b2838396","type":"Grid"},{"attributes":{},"id":"4bac474f-4d14-40d1-999b-19618889b7fb","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"72648223-6f74-4e43-ac0b-666ad992cd5b","type":"LinearAxis"}],"left":[{"id":"9903d19c-8953-41e6-ab38-dfc515a55fc6","type":"LinearAxis"}],"plot_height":300,"plot_width":630,"renderers":[{"id":"72648223-6f74-4e43-ac0b-666ad992cd5b","type":"LinearAxis"},{"id":"334c04c5-a757-4482-9577-a8b6b2838396","type":"Grid"},{"id":"9903d19c-8953-41e6-ab38-dfc515a55fc6","type":"LinearAxis"},{"id":"63113887-84d0-4396-99a7-ea84c3fc2931","type":"Grid"},{"id":"1cdb614b-b299-4d4d-b922-9cae6f33dc8b","type":"BoxAnnotation"},{"id":"8fcb37ba-0358-4512-9849-5652d7d2e0ac","type":"GlyphRenderer"}],"title":null,"tool_events":{"id":"824c8f52-858f-4eba-899d-566dd54395ac","type":"ToolEvents"},"toolbar":{"id":"7d022790-d08c-4438-a6c4-c7d3ce600e3d","type":"Toolbar"},"x_range":{"id":"4b067397-c324-446f-801e-037d6d370d6c","type":"DataRange1d"},"y_range":{"id":"e9fdf827-8100-4643-9211-27c265387240","type":"DataRange1d"}},"id":"64e12061-60d8-4c69-9c46-7e906f73e5b9","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"1cdb614b-b299-4d4d-b922-9cae6f33dc8b","type":"BoxAnnotation"},"plot":{"id":"64e12061-60d8-4c69-9c46-7e906f73e5b9","subtype":"Figure","type":"Plot"}},"id":"608f41f2-c85a-4f44-ba80-bed83ca8a8a3","type":"BoxZoomTool"},{"attributes":{},"id":"9cb6da7f-9e11-4651-9fca-807ace3bfa64","type":"BasicTicker"},{"attributes":{"plot":{"id":"64e12061-60d8-4c69-9c46-7e906f73e5b9","subtype":"Figure","type":"Plot"}},"id":"b8e718b5-a96c-48f5-87a7-620b9b33da75","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"49e1725c-18c7-47ac-be04-7d1eccccc018","type":"Circle"},{"attributes":{},"id":"d38dd3ee-85ea-492f-a378-ee434e1eef93","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a7b34344-f404-49ad-abbe-6c228b9fb010","type":"PanTool"},{"id":"b8e718b5-a96c-48f5-87a7-620b9b33da75","type":"WheelZoomTool"},{"id":"608f41f2-c85a-4f44-ba80-bed83ca8a8a3","type":"BoxZoomTool"},{"id":"d12479e6-6679-4891-8499-978b8f310e36","type":"SaveTool"},{"id":"c2d36b13-d855-420b-acfe-79723d987870","type":"ResetTool"},{"id":"4755427d-3df4-41df-a487-046bd8d3dcb8","type":"HelpTool"}]},"id":"7d022790-d08c-4438-a6c4-c7d3ce600e3d","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[60]},"y":{"__ndarray__":"...","dtype":"float64","shape":[60]}}},"id":"a8438162-5362-48b2-9a80-ce9fee419d4a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"64e12061-60d8-4c69-9c46-7e906f73e5b9","subtype":"Figure","type":"Plot"}},"id":"4755427d-3df4-41df-a487-046bd8d3dcb8","type":"HelpTool"},{"attributes":{"data_source":{"id":"a8438162-5362-48b2-9a80-ce9fee419d4a","type":"ColumnDataSource"},"glyph":{"id":"b99cc304-fcb3-4b52-8724-0552867259c0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"49e1725c-18c7-47ac-be04 ...

# %% [markdown]
# This resembles a sine curve but not exactly because of the noise. We’ll use this as an example to test different scenarios in this article. Lets try to estimate the sine function using polynomial regression with powers of x form 1 to 15. Lets add a column for each power upto 15 in our dataframe. This can be accomplished using the following code:

# %%
for i in range(2,16):  #power of 1 is already there
    data['x_{}'.format(i)] = data['x']**i
print(data.head())
# Out:
#           x         y       x_2       x_3       x_4       x_5       x_6  \
# 0  1.047198  1.065763  1.096623  1.148381  1.202581  1.259340  1.318778
# 1  1.117011  1.006086  1.247713  1.393709  1.556788  1.738948  1.942424
# 2  1.186824  0.695374  1.408551  1.671702  1.984016  2.354677  2.794587
# 3  1.256637  0.949799  1.579137  1.984402  2.493673  3.133642  3.937850
# 4  1.326450  1.063496  1.759470  2.333850  3.095735  4.106339  5.446854
#
#         x_7       x_8        x_9       x_10       x_11       x_12       x_13  \
# 0  1.381021  1.446202   1.514459   1.585938   1.660790   1.739176   1.821260
# 1  2.169709  2.423588   2.707173   3.023942   3.377775   3.773011   4.214494
# 2  3.316683  3.936319   4.671717   5.544505   6.580351   7.809718   9.268760
# 3  4.948448  6.218404   7.814277   9.819710  12.339811  15.506664  19.486248
# 4  7.224981  9.583578  12.712139  16.862020  22.366630  29.668222  39.353420
#
#         x_14       x_15
# 0   1.907219   1.997235
# 1   4.707635   5.258479
# 2  11.000386  13.055521
# 3  24.487142  30.771450
# 4  52.200353  69.241170

# %%
def linear_power_model(model, data, power):
    #initialize predictors:
    predictors=['x']
    if power >= 2:
        predictors += ['x_{}'.format(i) for i in range(2,power+1)]
    
    #Fit the model
    model.fit(data[predictors],data['y'])
    y_pred = model.predict(data[predictors])
 
    #Return the result in pre-defined format
    rss = sum((y_pred-data['y'])**2)
    ret = [rss]
    ret.extend([model.intercept_])
    ret.extend(model.coef_)
    return ret, y_pred

# %%
results = {}
regr = linear_model.LinearRegression(normalize=True)
for i in range(1,16):
    results[i] = linear_power_model(regr, data, i)

# %%
grid = []
for m in [1, 3, 6, 9, 12, 15]:
    p = bk.figure(plot_width=230, plot_height=300, title='Plot for power {}'.format(m))
    p.circle(data['x'], data['y'],)
    p.line(data['x'], results[m][1], color='firebrick')
    grid.append(p)
bk.show(gridplot(grid, ncols=3))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f91fddf4-3a14-4429-88c8-eb24c9c49a7f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f91fddf4-3a14-4429-88c8-eb24c9c49a7f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f91fddf4-3a14-4429-88c8-eb24c9c49a7f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f91fddf4-3a14-4429-88c8-eb24c9c49a7f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d4064e9-dfee-4dde-a748-12cdd5b91783":{"roots":{"references":[{"attributes":{"line_color":{"value":"firebrick"},"x":{"field":"x"},"y":{"field":"y"}},"id":"006b6079-de25-415f-9fae-4549e37472e2","type":"Line"},{"attributes":{"plot":{"id":"9c2c6c36-3051-4bd8-8089-420c1c2b799c","subtype":"Figure","type":"Plot"}},"id":"f48acbab-ca3a-4469-aad5-2dd0a106a11e","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4758ef10-94d6-4110-acac-fb56db511227","type":"Circle"},{"attributes":{"below":[{"id":"442cebe8-1697-48c8-94db-a27d2ee23d35","type":"LinearAxis"}],"left":[{"id":"3d34f54c-352b-4b57-a99c-0c9bd932fe8c","type":"LinearAxis"}],"plot_height":300,"plot_width":230,"renderers":[{"id":"442cebe8-1697-48c8-94db-a27d2ee23d35","type":"LinearAxis"},{"id":"4404051b-4f58-414a-a696-30b09f22ba4c","type":"Grid"},{"id":"3d34f54c-352b-4b57-a99c-0c9bd932fe8c","type":"LinearAxis"},{"id":"d74c824f-3227-434e-b70c-536f6ad5f5c5","type":"Grid"},{"id":"10835f07-47b4-435c-a7c1-26fec61993b9","type":"BoxAnnotation"},{"id":"bacc47f8-2f4b-40a0-a785-d8512284e934","type":"GlyphRenderer"},{"id":"c5b9cecc-4964-4dae-a290-fd4be07d580b","type":"GlyphRenderer"}],"title":{"id":"ef396d0f-5e90-4332-9abf-8f53bb0ee5de","type":"Title"},"tool_events":{"id":"570b4bf8-cd84-473a-aba0-bf087ef7b5fa","type":"ToolEvents"},"toolbar":{"id":"d8521a96-9fdc-4e76-abf6-05cc2dfed84b","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"d3147739-633b-4c71-9559-aab55f4abbb2","type":"DataRange1d"},"y_range":{"id":"76fade73-19ae-4358-8c15-daf5a140b9dd","type":"DataRange1d"}},"id":"0077d1eb-34ef-47aa-8fcc-38841917e090","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"0077d1eb-34ef-47aa-8fcc-38841917e090","subtype":"Figure","type":"Plot"},{"id":"9c2c6c36-3051-4bd8-8089-420c1c2b799c","subtype":"Figure","type":"Plot"},{"id":"6e98fbb4-b9e1-4e2d-b11d-3d24813a3ccc","subtype":"Figure","type":"Plot"}]},"id":"e18c2bf6-6b5f-4e35-822a-23de1a9747a6","type":"Row"},{"attributes":{"data_source":{"id":"0f70c92c-43e8-49cc-903e-536c7f1d6dfa","type":"ColumnDataSource"},"glyph":{"id":"f735e7bf-2de9-43e1-aba0-f770062eda9c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"cae13830-a327-4e18-99d6-a41ce962fc1e","type":"Circle"},"selection_glyph":null},"id":"b6bf2195-c127-4881-af05-af1515432a17","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"e8e78568-48f9-40ac-8567-6811d41f5dfa","type":"DataRange1d"},{"attributes":{"formatter":{"id":"17d1bf39-016a-485d-9875-556041472dd6","type":"BasicTickFormatter"},"plot":{"id":"9c2c6c36-3051-4bd8-8089-420c1c2b799c","subtype":"Figure","type":"Plot"},"ticker":{"id":"990bf34d-10ff-4383-a56e-82b7f6bd16a7","type":"BasicTicker"}},"id":"4fb6bf9f-c09b-463a-8c9f-923484ddcf49","type":"LinearAxis"},{"attributes":{"plot":{"id":"6e98fbb4-b9e1-4e2d-b11d-3d24813a3ccc","subtype":"Figure","type":"Plot"}},"id":"a5d4ed7f-31ca-457d-95b8-4de0ef485924","type":"PanTool"},{"attributes":{"plot":{"id":"e0f605b1-fc29-4938-8dbf-908576f2cc23","subtype":"Figure","type":"Plot"}},"id":"83961d68-4bba-476d-aaeb-461dccd7823b","type":"PanTool"},{"attributes":{"plot":{"id":"e0f605b1-fc29-4938-8dbf-908576f2cc23","subtype":"Figure","type":"Plot"}},"id":"c96af75f-4951-4923-81f2-3300b987f076","type":"SaveTool"},{"attributes":{"plot":{"id":"0077d1eb-34ef-47aa-8fcc-38841917e090","subtype":"Figure","type":"Plot"}},"id":"d036f306-ffd9-44e8-b658-8d9985f6e561","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[60]},"y":{"__ndarray__":"...","dtype":"float64","shape":[60]}}},"id":"eccd26ca-d817-4bf1-b2d1-c41e719e9e46","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Plot for power 6"},"id":"6035b77b-be66-4459-938a-3341720aa57e","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","ac ...

# %%
col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['model_pow_%d'%i for i in range(1,16)]
coef_matrix_simple = pd.DataFrame(index=ind, columns=col)
for i in range(1,16):
    coef_matrix_simple.iloc[i-1,0:i+2] = results[i][0]

# %%
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_simple
# Out:
#               rss intercept coef_x_1 coef_x_2 coef_x_3 coef_x_4 coef_x_5  \
# model_pow_1   3.3         2    -0.62      NaN      NaN      NaN      NaN
# model_pow_2   3.3       1.9    -0.58   -0.006      NaN      NaN      NaN
# model_pow_3   1.1      -1.1        3     -1.3     0.14      NaN      NaN
# model_pow_4   1.1     -0.27      1.7    -0.53   -0.036    0.014      NaN
# model_pow_5     1         3     -5.1      4.7     -1.9     0.33   -0.021
# model_pow_6  0.99      -2.8      9.5     -9.7      5.2     -1.6     0.23
# model_pow_7  0.93        19      -56       69      -45       17     -3.5
# model_pow_8  0.92        43 -1.4e+02  1.8e+02 -1.3e+02       58      -15
# model_pow_9  0.87   1.7e+02 -6.1e+02  9.6e+02 -8.5e+02  4.6e+02 -1.6e+02
# model_pow_10 0.87   1.4e+02 -4.9e+02  7.3e+02   -6e+02  2.9e+02      -87
# model_pow_11 0.87       -75  5.1e+02 -1.3e+03  1.9e+03 -1.6e+03  9.1e+02
# model_pow_12 0.87  -3.4e+02  1.9e+03 -4.4e+03    6e+03 -5.2e+03  3.1e+03
# model_pow_13 0.86   3.2e+03 -1.8e+04  4.5e+04 -6.7e+04  6.6e+04 -4.6e+04
# model_pow_14 0.79   2.4e+04 -1.4e+05  3.8e+05 -6.1e+05  6.6e+05   -5e+05
# model_pow_15  0.7  -3.6e+04  2.4e+05 -7.5e+05  1.4e+06 -1.7e+06  1.5e+06
#
#              coef_x_6 coef_x_7 coef_x_8 coef_x_9 coef_x_10 coef_x_11  \
# model_pow_1       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_2       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_3       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_4       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_5       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_6    -0.014      NaN      NaN      NaN       NaN       NaN
# model_pow_7       0.4   -0.019      NaN      NaN       NaN       NaN
# model_pow_8       2.4    -0.21   0.0077      NaN       NaN       NaN
# model_pow_9        37     -5.2     0.42   -0.015       NaN       NaN
# model_pow_10       15    -0.81    -0.14    0.026   -0.0013       NaN
# model_pow_11 -3.5e+02       91      -16      1.8     -0.12    0.0034
# model_pow_12 -1.3e+03  3.8e+02      -80       12      -1.1     0.062
# model_pow_13  2.3e+04 -8.5e+03  2.3e+03 -4.5e+02        62      -5.7
# model_pow_14  2.8e+05 -1.2e+05  3.7e+04 -8.5e+03   1.5e+03  -1.8e+02
# model_pow_15   -1e+06    5e+05 -1.9e+05  5.4e+04  -1.2e+04   1.9e+03
#
#              coef_x_12 coef_x_13 coef_x_14 coef_x_15
# model_pow_1        NaN       NaN       NaN       NaN
# model_pow_2        NaN       NaN       NaN       NaN
# model_pow_3        NaN       NaN       NaN       NaN
# model_pow_4        NaN       NaN       NaN       NaN
# model_pow_5        NaN       NaN       NaN       NaN
# model_pow_6        NaN       NaN       NaN       NaN
# model_pow_7        NaN       NaN       NaN       NaN
# model_pow_8        NaN       NaN       NaN       NaN
# model_pow_9        NaN       NaN       NaN       NaN
# model_pow_10       NaN       NaN       NaN       NaN
# model_pow_11       NaN       NaN       NaN       NaN
# model_pow_12   -0.0016       NaN       NaN       NaN
# model_pow_13      0.31   -0.0078       NaN       NaN
# model_pow_14        15     -0.73     0.017       NaN
# model_pow_15  -2.2e+02        17     -0.81     0.018

# %% [markdown]
# It is clearly evident that the size of coefficients increase exponentially with increase in model complexity. I hope this gives some intuition into why putting a constraint on the magnitude of coefficients can be a good idea to reduce model complexity.
#
# Lets try to understand this even better.
#
# What does a large coefficient signify? It means that we’re putting a lot of emphasis on that feature, i.e. the particular feature is a good predictor for the outcome. When it becomes too large, the algorithm starts modelling intricate relations to estimate the output and ends up overfitting to the particular training data.

# %% [markdown]
# ## 2 Ridge Regression

# %% [markdown]
# Linear Regression rely on the independence of the model terms. When terms are correlated and the columns of the design matrix $X$; have an approximate linear dependence, the matrix $(X^TX)^{-1}$ becomes
# close to singular. As a result, the least-squares estimate becomes highly sensitive to random errors in the observed response *y*, producing a large variance. This situation of multicollinearity can arise, for example, when data are collected without an experimental design.
#
# The ridge coefficients minimize a penalized residual sum of squares:
#
# $$ \underset{w}{min} \|Xw -y\|_2^2 + \alpha \|w\|_2^2$$
#
# Here, positive $\alpha  \geq 0 \hspace{2 pt}$ is a complexity parameter that controls the amount of shrinkage: the larger the value of $\alpha$, the greater the amount of shrinkage and thus the coefficients become more robust to collinearity.
#
# One thing is for sure that any non-zero value would give values less than that of simple linear regression. By how much? We’ll find out soon. Lets see ridge regression in action on the same problem as above.

# %%
alpha_ridge = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]
results = {}
for alpha in alpha_ridge:
    ridgereg = linear_model.Ridge(alpha=alpha,normalize=True)
    results[alpha] = linear_power_model(ridgereg, data, 15)

# %%
grid = []
for m in [1e-15, 1e-10, 1e-3, 1e-2, 1, 5]:
    p = bk.figure(plot_width=230, plot_height=300, title='Plot for alpha {}'.format(m))
    p.circle(data['x'], data['y'],)
    p.line(data['x'], results[m][1], color='firebrick')
    grid.append(p)
bk.show(gridplot(grid, ncols=3))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="94a59e87-c0c7-4c73-8c7e-ef4e941dc3df"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("94a59e87-c0c7-4c73-8c7e-ef4e941dc3df").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("94a59e87-c0c7-4c73-8c7e-ef4e941dc3df");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '94a59e87-c0c7-4c73-8c7e-ef4e941dc3df' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c2cec0e3-9737-4b5c-a91c-f39d55e12bfb":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ecffba0-54ac-40ee-ab3b-88487cab3dad","type":"Line"},{"attributes":{"line_color":{"value":"firebrick"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d44d637-e990-413b-90be-1b59633ba642","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"64c5cc1d-1078-47fd-98bb-3f05c1595c40","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae2b1eed-9594-4224-89c4-705944c9a2dc","type":"BasicTicker"}},"id":"394bf281-19fa-4a54-ac7e-8be2d010a223","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e9f6100a-2592-4777-b2e8-0f23bf4857ad","type":"Circle"},{"attributes":{},"id":"cd167856-691f-4766-b433-e7159b3aeb5a","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"b53a2893-4593-4401-8f9d-85496d2d1a39","type":"DataRange1d"},{"attributes":{},"id":"ae2b1eed-9594-4224-89c4-705944c9a2dc","type":"BasicTicker"},{"attributes":{"plot":{"id":"17594bd6-4f15-4b9e-a5bf-e91a95b7e59b","subtype":"Figure","type":"Plot"}},"id":"19f8f3d3-d9c3-47ea-bad1-2322c1907acc","type":"SaveTool"},{"attributes":{"plot":{"id":"47cbff78-d060-43fd-8ae3-04f406d53739","subtype":"Figure","type":"Plot"}},"id":"ce15edd7-9576-4618-9930-59161467dee8","type":"HelpTool"},{"attributes":{},"id":"80687a04-0507-4627-8076-325f520efc47","type":"BasicTicker"},{"attributes":{},"id":"ea9891e2-c4c2-43b4-859e-9bb099e4987f","type":"BasicTicker"},{"attributes":{"plot":{"id":"9b16ac06-97eb-4274-af6a-19bc7d813d30","subtype":"Figure","type":"Plot"},"ticker":{"id":"747c7efe-e9d4-4d44-b82e-303f41b332a8","type":"BasicTicker"}},"id":"96a60f81-e808-472d-b143-2a9c59be6226","type":"Grid"},{"attributes":{},"id":"ecd7734a-5bff-4dd3-8a96-d482d842cf03","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"17594bd6-4f15-4b9e-a5bf-e91a95b7e59b","subtype":"Figure","type":"Plot"},"ticker":{"id":"80687a04-0507-4627-8076-325f520efc47","type":"BasicTicker"}},"id":"85022a46-1c14-4920-8f99-7d03f134591b","type":"Grid"},{"attributes":{"plot":{"id":"9b16ac06-97eb-4274-af6a-19bc7d813d30","subtype":"Figure","type":"Plot"}},"id":"4d0562f2-253b-499f-a27a-212a7078fe4a","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"19e0fc90-e94f-4163-bbb2-3fa131f55c0c","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"e93ac1f9-0b9c-4b4d-9d18-447aebb1e704","type":"DataRange1d"},{"attributes":{"plot":{"id":"9b16ac06-97eb-4274-af6a-19bc7d813d30","subtype":"Figure","type":"Plot"}},"id":"34fb29a3-ac6b-4050-9aad-68a55069dfb3","type":"PanTool"},{"attributes":{"plot":{"id":"47cbff78-d060-43fd-8ae3-04f406d53739","subtype":"Figure","type":"Plot"}},"id":"73dce05e-0769-41df-8bd0-973b7921caba","type":"SaveTool"},{"attributes":{},"id":"5b2d86d2-fb1c-4eb0-b5e0-5ac624523abc","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"1e32941e-4314-45b7-92ad-c28df94de4d7","type":"Row"},{"id":"475a27b3-7f19-45e7-af67-e767eda9330e","type":"Row"}]},"id":"09ca7595-8a68-45b8-b88c-95de3000393e","type":"Column"},{"attributes":{"formatter":{"id":"80a6c3c7-6562-4d2d-8b7c-73444ca006bd","type":"BasicTickFormatter"},"plot":{"id":"47cbff78-d060-43fd-8ae3-04f406d53739","subtype":"Figure","type":"Plot"},"ticker":{"id":"233dc685-195e-4218-83e2-042018c40938","type":"BasicTicker"}},"id":"4b5f4adb-fd46-433f-ac8f-285698ec353f","type":"LinearAxis"},{"attributes":{"plot":{"id":"9b16ac06-97eb-4274-af6a-19bc7d813d30","subtype":"Figure","type":"Plot"}},"id":"6ece2752-afe4-466d-be62-2c39cca40300","type":"SaveTool"},{"attributes":{"formatter":{"id":"88f0e176-8c12-4e9a-ae5f-a ...

# %%
col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['alpha_%.2g'%alpha_ridge[i] for i in range(0,10)]
coef_matrix_ridge = pd.DataFrame(index=ind, columns=col)

for i,e in enumerate(alpha_ridge):
    coef_matrix_ridge.iloc[i,] = results[e][0]

# %%
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_simple
# Out:
#               rss intercept coef_x_1 coef_x_2 coef_x_3 coef_x_4 coef_x_5  \
# model_pow_1   3.3         2    -0.62      NaN      NaN      NaN      NaN
# model_pow_2   3.3       1.9    -0.58   -0.006      NaN      NaN      NaN
# model_pow_3   1.1      -1.1        3     -1.3     0.14      NaN      NaN
# model_pow_4   1.1     -0.27      1.7    -0.53   -0.036    0.014      NaN
# model_pow_5     1         3     -5.1      4.7     -1.9     0.33   -0.021
# model_pow_6  0.99      -2.8      9.5     -9.7      5.2     -1.6     0.23
# model_pow_7  0.93        19      -56       69      -45       17     -3.5
# model_pow_8  0.92        43 -1.4e+02  1.8e+02 -1.3e+02       58      -15
# model_pow_9  0.87   1.7e+02 -6.1e+02  9.6e+02 -8.5e+02  4.6e+02 -1.6e+02
# model_pow_10 0.87   1.4e+02 -4.9e+02  7.3e+02   -6e+02  2.9e+02      -87
# model_pow_11 0.87       -75  5.1e+02 -1.3e+03  1.9e+03 -1.6e+03  9.1e+02
# model_pow_12 0.87  -3.4e+02  1.9e+03 -4.4e+03    6e+03 -5.2e+03  3.1e+03
# model_pow_13 0.86   3.2e+03 -1.8e+04  4.5e+04 -6.7e+04  6.6e+04 -4.6e+04
# model_pow_14 0.79   2.4e+04 -1.4e+05  3.8e+05 -6.1e+05  6.6e+05   -5e+05
# model_pow_15  0.7  -3.6e+04  2.4e+05 -7.5e+05  1.4e+06 -1.7e+06  1.5e+06
#
#              coef_x_6 coef_x_7 coef_x_8 coef_x_9 coef_x_10 coef_x_11  \
# model_pow_1       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_2       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_3       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_4       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_5       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_6    -0.014      NaN      NaN      NaN       NaN       NaN
# model_pow_7       0.4   -0.019      NaN      NaN       NaN       NaN
# model_pow_8       2.4    -0.21   0.0077      NaN       NaN       NaN
# model_pow_9        37     -5.2     0.42   -0.015       NaN       NaN
# model_pow_10       15    -0.81    -0.14    0.026   -0.0013       NaN
# model_pow_11 -3.5e+02       91      -16      1.8     -0.12    0.0034
# model_pow_12 -1.3e+03  3.8e+02      -80       12      -1.1     0.062
# model_pow_13  2.3e+04 -8.5e+03  2.3e+03 -4.5e+02        62      -5.7
# model_pow_14  2.8e+05 -1.2e+05  3.7e+04 -8.5e+03   1.5e+03  -1.8e+02
# model_pow_15   -1e+06    5e+05 -1.9e+05  5.4e+04  -1.2e+04   1.9e+03
#
#              coef_x_12 coef_x_13 coef_x_14 coef_x_15
# model_pow_1        NaN       NaN       NaN       NaN
# model_pow_2        NaN       NaN       NaN       NaN
# model_pow_3        NaN       NaN       NaN       NaN
# model_pow_4        NaN       NaN       NaN       NaN
# model_pow_5        NaN       NaN       NaN       NaN
# model_pow_6        NaN       NaN       NaN       NaN
# model_pow_7        NaN       NaN       NaN       NaN
# model_pow_8        NaN       NaN       NaN       NaN
# model_pow_9        NaN       NaN       NaN       NaN
# model_pow_10       NaN       NaN       NaN       NaN
# model_pow_11       NaN       NaN       NaN       NaN
# model_pow_12   -0.0016       NaN       NaN       NaN
# model_pow_13      0.31   -0.0078       NaN       NaN
# model_pow_14        15     -0.73     0.017       NaN
# model_pow_15  -2.2e+02        17     -0.81     0.018

# %% [markdown]
# This straight away gives us the following inferences:
#
# * The RSS increases with increase in alpha, this model complexity reduces
# * An alpha as small as 1e-15 gives us significant reduction in magnitude of coefficients. How? Compare the coefficients in the first row of this table to the last row of simple linear regression table.
# * High alpha values can lead to significant underfitting. Note the rapid increase in RSS for values of alpha greater than 1
# * Though the coefficients are very very small, they are NOT zero.
#
# The first 3 are very intuitive. But #4 is also a crucial observation. Let’s reconfirm the same by determining the number of zeros in each row of the coefficients data set:

# %%
coef_matrix_ridge.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha_1e-15     0
# alpha_1e-10     0
# alpha_1e-08     0
# alpha_0.0001    0
# alpha_0.001     0
# alpha_0.01      0
# alpha_1         0
# alpha_5         0
# alpha_10        0
# alpha_20        0
# dtype: int64

# %% [markdown]
# This confirms that all the 15 coefficients are greater than zero in magnitude (can be +ve or -ve). Remember this observation and have a look again until its clear. This will play an important role in later while comparing ridge with lasso regression.

# %% [markdown]
# ## 3 LASSO

# %% [markdown]
# The Lasso is a linear model that estimates sparse coefficients. It is useful in some contexts due to its tendency to prefer solutions with fewer parameter values, effectively reducing the number of variables upon which the given solution is dependent. For this reason, the Lasso and its variants are fundamental to the field of compressed sensing. Under certain conditions, it can recover the exact set of non-zero weights.
#
# Mathematically, it consists of a linear model trained with $\ell_1$ prior as regularizer. The objective function to minimize is:
#
# $$\underset{w}{min\,} { \frac{1}{2n_{samples}} ||X w - y||_2 ^ 2 + \alpha ||w||_1}$$
#
# The lasso estimate thus solves the minimization of the least-squares penalty with $\alpha$ $||w||_1$ added, where $\alpha$ is a constant and $||w||_1$ is the $\ell_1$-norm of the parameter vector.

# %%
alpha_lasso = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]
results = {}
for alpha in alpha_lasso:
    lassoreg = linear_model.Lasso(alpha=alpha, normalize=True)
    results[alpha] = linear_power_model(lassoreg, data, 15)
# Out:
# /home/matteo/anaconda3/envs/addtrain/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
grid = []
for m in [1e-15, 1e-10, 1e-3, 1e-4, 1e-2, 1]:
    p = bk.figure(plot_width=230, plot_height=300, title='Plot for alpha {}'.format(m))
    p.circle(data['x'], data['y'],)
    p.line(data['x'], results[m][1], color='firebrick')
    grid.append(p)
bk.show(gridplot(grid, ncols=3))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d8468f4c-782a-43f0-a18c-8d409afac72c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d8468f4c-782a-43f0-a18c-8d409afac72c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d8468f4c-782a-43f0-a18c-8d409afac72c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd8468f4c-782a-43f0-a18c-8d409afac72c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4910251e-7cda-4375-a7dd-b23f81a2d636":{"roots":{"references":[{"attributes":{"plot":{"id":"6375e815-11ee-43a9-ad48-66314d467b69","subtype":"Figure","type":"Plot"}},"id":"9f3dbf82-8343-44a1-9089-07067347e62b","type":"PanTool"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"260f5e98-07bf-48a2-8cec-1f3159832f85","type":"PanTool"},{"id":"8ddd358a-f539-42e6-a51c-f5f93068c893","type":"WheelZoomTool"},{"id":"5ed9a27f-79ad-4fda-9014-8ba9b4f03477","type":"BoxZoomTool"},{"id":"056bae02-541a-472b-b776-3bb70072f3f5","type":"SaveTool"},{"id":"c5bd588b-8edd-4fee-9964-998c5492c78d","type":"ResetTool"},{"id":"8edc5152-20bb-40e1-a39f-ace5dc8eb9c9","type":"HelpTool"},{"id":"a0bb4564-970a-4907-ad47-a19c4a16e156","type":"PanTool"},{"id":"36d7e3f1-b059-46c1-8f85-e66d48cf6b98","type":"WheelZoomTool"},{"id":"b761132d-6208-4fdf-b1ff-2e9fc0e71915","type":"BoxZoomTool"},{"id":"c8cc485b-8f1b-4fe3-ad09-22faf57b70b3","type":"SaveTool"},{"id":"df1226b1-cf25-45f2-8aa0-4806d4724b24","type":"ResetTool"},{"id":"a3cf02f2-6b78-4e34-bc6d-6fa8c89ea716","type":"HelpTool"},{"id":"34930a04-79a6-47a1-bdf7-816dde73db27","type":"PanTool"},{"id":"85f63d7f-3b62-4f5d-a0b8-21ea9b840495","type":"WheelZoomTool"},{"id":"0f176690-0c04-41ee-9e18-49e70ebef894","type":"BoxZoomTool"},{"id":"dd22a6fc-8518-4a75-aeb0-d25fb20b032d","type":"SaveTool"},{"id":"fc03f70b-55a5-4704-91ac-255d476bb2ee","type":"ResetTool"},{"id":"75fe5c4e-e05b-4bc7-9022-83c745dee51d","type":"HelpTool"},{"id":"b47e245c-5cff-495f-94b4-be26ebd237d8","type":"PanTool"},{"id":"50b5cb26-899b-4d5c-8043-a3122eb60c0d","type":"WheelZoomTool"},{"id":"e5f128ca-5494-4b1f-b05e-312c5c5f15f8","type":"BoxZoomTool"},{"id":"f0c32e4b-7a04-4340-a1cb-9c9f89edf089","type":"SaveTool"},{"id":"b0812242-e98e-4c46-a1e1-3674a49da1fd","type":"ResetTool"},{"id":"4118b592-616c-474a-9712-e4bcb090e6e7","type":"HelpTool"},{"id":"9f3dbf82-8343-44a1-9089-07067347e62b","type":"PanTool"},{"id":"dca788cc-86f9-4022-9a4b-23bb332492ed","type":"WheelZoomTool"},{"id":"a00893d3-0a57-4ca6-86af-7571d240864f","type":"BoxZoomTool"},{"id":"a441ca31-3d6e-48f9-a995-6c0940e1fdd0","type":"SaveTool"},{"id":"d04bd941-ed81-4958-b68e-703babfbf52f","type":"ResetTool"},{"id":"4177eb1a-5fae-4c62-a3a8-401494ebb78f","type":"HelpTool"},{"id":"e21cf10a-93dd-4a0c-8d78-edda6c90eee6","type":"PanTool"},{"id":"8fef250e-5591-4ecc-ae03-6e875f7cb23c","type":"WheelZoomTool"},{"id":"2ae59659-999a-44fa-b59c-d4612882aa66","type":"BoxZoomTool"},{"id":"52125261-e8c2-47e4-bade-5aaf46734eaa","type":"SaveTool"},{"id":"20c8fb02-8183-4f15-9ea0-ffccc93c4fd3","type":"ResetTool"},{"id":"a1f83f41-f6fd-47ba-b30a-5e511f5d7b97","type":"HelpTool"}]},"id":"03d1c6a3-f66c-4aed-a72e-8401afdd1e22","type":"ToolbarBox"},{"attributes":{"callback":null},"id":"80086038-a9d4-45e4-a02a-17c6e12c8d8f","type":"DataRange1d"},{"attributes":{"plot":{"id":"45a2237b-4a71-4a87-8218-32b9c88b4eb1","subtype":"Figure","type":"Plot"}},"id":"a0bb4564-970a-4907-ad47-a19c4a16e156","type":"PanTool"},{"attributes":{"children":[{"id":"84455985-92bd-4ad5-b596-21b4fd00170e","subtype":"Figure","type":"Plot"},{"id":"45a2237b-4a71-4a87-8218-32b9c88b4eb1","subtype":"Figure","type":"Plot"},{"id":"a9b56b28-a38e-45a9-a2b7-f358be3e5db3","subtype":"Figure","type":"Plot"}]},"id":"2460daff-9901-48e2-abdd-d7b61fbdffe6","type":"Row"},{"attributes":{},"id":"d3611d3b-ffd8-4388-b008-0f25cc550bf7","type":"BasicTicker"},{"attributes":{},"id":"b39530e2-60f5-420c-97f5-2ea463ec5c6c","type":"BasicTicker"},{"attributes":{"plot":{"id":"93763b0c-7f5d-4fe1-8b50-1dece601167f","subtype":"Figure","type":"Plot"}},"id":"20c8fb02-8183-4f15-9ea0-ffccc93c4fd3","type":"ResetTool"},{"attributes":{"formatter":{"id":"3fe2f1e1-6f7e-48d9-ae17-f492cecfef50","type":"BasicTickFormatter"},"plot":{"id":"2de94ca8-9be9-47f4-877f-7bf5724d7554","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb0a2295-0495-48a2-8a46-97fd7bbad733","type":"BasicTicker"}},"id":"44555f5a-2ebd-4173-ad87-46cbfda3c907","type":"LinearAxis"} ...

# %% [markdown]
# This again tells us that the model complexity decreases with increase in the values of alpha. But notice the straight line at alpha=1. Appears a bit strange to me. Let’s explore this further by looking at the coefficients:

# %%
col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['alpha_%.2g'%alpha_lasso[i] for i in range(0,10)]
coef_matrix_lasso = pd.DataFrame(index=ind, columns=col)

for i,e in enumerate(alpha_lasso):
    coef_matrix_lasso.iloc[i,] = results[e][0]

# %%
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_lasso
# Out:
#               rss intercept coef_x_1 coef_x_2 coef_x_3 coef_x_4 coef_x_5  \
# alpha_1e-15  0.97      0.14      1.1     -0.3   -0.024 -0.00052   0.0003
# alpha_1e-10  0.97      0.14      1.1     -0.3   -0.024 -0.00052   0.0003
# alpha_1e-08  0.97      0.14      1.1     -0.3   -0.024 -0.00052   0.0003
# alpha_0.0001    1      0.61      0.6    -0.19   -0.022       -0       -0
# alpha_0.001   1.7       1.3       -0    -0.13       -0       -0       -0
# alpha_0.01    3.6       1.8    -0.55 -0.00056       -0       -0       -0
# alpha_1        37     0.038       -0       -0       -0       -0       -0
# alpha_5        37     0.038       -0       -0       -0       -0       -0
# alpha_10       37     0.038       -0       -0       -0       -0       -0
# alpha_20       37     0.038       -0       -0       -0       -0       -0
#
#              coef_x_6 coef_x_7 coef_x_8 coef_x_9 coef_x_10 coef_x_11  \
# alpha_1e-15   8.8e-05  1.7e-05  2.9e-06  4.1e-07   4.7e-08   2.9e-09
# alpha_1e-10   8.8e-05  1.7e-05  2.9e-06  4.1e-07   4.7e-08   2.9e-09
# alpha_1e-08   8.8e-05  1.7e-05  2.9e-06  4.1e-07   4.7e-08   2.9e-09
# alpha_0.0001  1.1e-05  2.4e-05  3.2e-06  3.2e-07   4.4e-09         0
# alpha_0.001         0        0        0        0         0   1.5e-08
# alpha_0.01         -0       -0       -0       -0         0         0
# alpha_1            -0       -0       -0       -0        -0        -0
# alpha_5            -0       -0       -0       -0        -0        -0
# alpha_10           -0       -0       -0       -0        -0        -0
# alpha_20           -0       -0       -0       -0        -0        -0
#
#              coef_x_12 coef_x_13 coef_x_14 coef_x_15
# alpha_1e-15   -5.3e-10    -3e-10    -9e-11  -2.3e-11
# alpha_1e-10   -5.3e-10    -3e-10    -9e-11  -2.3e-11
# alpha_1e-08   -5.3e-10    -3e-10    -9e-11  -2.3e-11
# alpha_0.0001         0        -0        -0  -2.9e-11
# alpha_0.001    7.5e-10         0         0         0
# alpha_0.01           0         0         0         0
# alpha_1             -0        -0        -0        -0
# alpha_5             -0        -0        -0        -0
# alpha_10            -0        -0        -0        -0
# alpha_20            -0        -0        -0        -0

# %% [markdown]
# Apart from the expected inference of higher RSS for higher alphas, we can see the following:
#
# * For the same values of alpha, the coefficients of lasso regression are much smaller as compared to that of ridge regression (compare row 1 of the 2 tables).
# * For the same alpha, lasso has higher RSS (poorer fit) as compared to ridge regression
# * Many of the coefficients are zero even for very small values of alpha
#
# The first two points might not be always true but will hold for many cases. The real difference from ridge is coming out in the last inference. Lets check the number of coefficients which are zero in each model using following code:

# %%
coef_matrix_lasso.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha_1e-15      0
# alpha_1e-10      0
# alpha_1e-08      0
# alpha_0.0001     6
# alpha_0.001     12
# alpha_0.01      13
# alpha_1         15
# alpha_5         15
# alpha_10        15
# alpha_20        15
# dtype: int64

# %% [markdown]
# We can observe that even for a small value of alpha, a significant number of coefficients are zero. This also explains the horizontal line fit for alpha=1 in the lasso plots, its just a baseline model! This phenomenon of most of the coefficients being zero is called "sparsity".
#
# Lasso can perform **feature selection**, especially where sparsity in data is a correct assumption, for example for problems where $p >> n$ such as micro array data.

# %% [markdown]
# ## 4 Remarks
#
# 1. Key Difference
#
#     * Ridge: It includes all (or none) of the features in the model. Thus, the major advantage of ridge regression is coefficient shrinkage and reducing model complexity.
#     * Lasso: Along with shrinking coefficients, lasso performs feature selection as well. (Remember the ‘selection‘ in the lasso full-form?) As we observed earlier, some of the coefficients become exactly zero, which is equivalent to the particular feature being excluded from the model.
#
# 2. Typical Use Cases
#
#     * Ridge: It is majorly used to prevent overfitting. Since it includes all the features, it is not very useful in case of exorbitantly high #features, say in millions, as it will pose computational challenges.
#     * Lasso: Since it provides sparse solutions, it is generally the model of choice (or some variant of this concept) for modelling cases where the #features are in millions or more. In such a case, getting a sparse solution is of great computational advantage as the features with zero coefficients can simply be ignored.
#
# 3. Presence of Highly Correlated Features
#
#     * Ridge: It generally works well even in presence of highly correlated features as it will include all of them in the model but the coefficients will be distributed among them depending on the correlation.
#     * Lasso: It arbitrarily selects any one feature among the highly correlated ones and reduced the coefficients of the rest to zero. Also, the chosen variable changes randomly with change in model parameters. This generally doesn’t work that well as compared to ridge regression.
#
# Along with Ridge and Lasso, **Elastic Net** is another useful techniques which combines both L1 and L2 regularization. It can be used to balance out the pros and cons of ridge and lasso regression. I encourage you to explore it further.

# %% [markdown]
# ## 5 ElasticNet

# %% [markdown]
# ElasticNet is a linear regression model trained with L1 and L2 prior as regularizer. This combination allows for learning a sparse model where few of the weights are non-zero like Lasso, while still maintaining the regularization properties of Ridge. We control the convex combination of L1 and L2 using the l1_ratio parameter.
#
# Elastic-net is useful when there are multiple features which are correlated with one another. Lasso is likely to pick one of these at random, while elastic-net is likely to pick both.
#
# A practical advantage of trading-off between Lasso and Ridge is it allows Elastic-Net to inherit some of Ridge’s stability under rotation.
#
# The objective function to minimize is in this case
#
# $$\underset{w}{min\,} { \frac{1}{2n_{samples}} ||X w - y||_2 ^ 2 + \alpha \rho ||w||_1 + \frac{\alpha(1-\rho)}{2} ||w||_2 ^ 2}$$
#
# The main difference between Lasso and Ridge is the penalty term they use. Ridge uses L2 penalty term which limits the size of the coefficient vector. Lasso uses L1 penalty which imposes sparsity among the coefficients and thus, makes the fitted model more interpretable. Elasticnet is introduced as a compromise between these two techniques, and has a penalty which is a mix of L1 and L2 norms.
#
# In the $p<<n$ case (p number of coefficients, n number of samples, which by the number of coefficients you show in the plots I guess it is the case here), the only real problem with the Lasso model is that when multiple features are correlated it tends to select one of then somewhat randomly.

# %%
from itertools import cycle
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import lasso_path, enet_path
from sklearn import datasets

diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

X /= X.std(axis=0)  # Standardize data (easier to set the l1_ratio parameter)

# Compute paths

eps = 5e-3  # the smaller it is the longer is the path

print("Computing regularization path using the lasso...")
alphas_lasso, coefs_lasso, _ = lasso_path(X, y, eps, fit_intercept=False)

print("Computing regularization path using the positive lasso...")
alphas_positive_lasso, coefs_positive_lasso, _ = lasso_path(
    X, y, eps, positive=True, fit_intercept=False)
print("Computing regularization path using the elastic net...")
alphas_enet, coefs_enet, _ = enet_path(
    X, y, eps=eps, l1_ratio=0.8, fit_intercept=False)

print("Computing regularization path using the positive elastic net...")
alphas_positive_enet, coefs_positive_enet, _ = enet_path(
    X, y, eps=eps, l1_ratio=0.8, positive=True, fit_intercept=False)

# Display results

plt.figure(1)
ax = plt.gca()

colors = cycle(['b', 'r', 'g', 'c', 'k'])
neg_log_alphas_lasso = -np.log10(alphas_lasso)
neg_log_alphas_enet = -np.log10(alphas_enet)
for coef_l, coef_e, c in zip(coefs_lasso, coefs_enet, colors):
    l1 = plt.plot(neg_log_alphas_lasso, coef_l, c=c)
    l2 = plt.plot(neg_log_alphas_enet, coef_e, linestyle='--', c=c)

plt.xlabel('-Log(alpha)')
plt.ylabel('coefficients')
plt.title('Lasso and Elastic-Net Paths')
plt.legend((l1[-1], l2[-1]), ('Lasso', 'Elastic-Net'), loc='lower left')
plt.axis('tight')


plt.figure(2)
ax = plt.gca()
neg_log_alphas_positive_lasso = -np.log10(alphas_positive_lasso)
for coef_l, coef_pl, c in zip(coefs_lasso, coefs_positive_lasso, colors):
    l1 = plt.plot(neg_log_alphas_lasso, coef_l, c=c)
    l2 = plt.plot(neg_log_alphas_positive_lasso, coef_pl, linestyle='--', c=c)

plt.xlabel('-Log(alpha)')
plt.ylabel('coefficients')
plt.title('Lasso and positive Lasso')
plt.legend((l1[-1], l2[-1]), ('Lasso', 'positive Lasso'), loc='lower left')
plt.axis('tight')


plt.figure(3)
ax = plt.gca()
neg_log_alphas_positive_enet = -np.log10(alphas_positive_enet)
for (coef_e, coef_pe, c) in zip(coefs_enet, coefs_positive_enet, colors):
    l1 = plt.plot(neg_log_alphas_enet, coef_e, c=c)
    l2 = plt.plot(neg_log_alphas_positive_enet, coef_pe, linestyle='--', c=c)

plt.xlabel('-Log(alpha)')
plt.ylabel('coefficients')
plt.title('Elastic-Net and positive Elastic-Net')
plt.legend((l1[-1], l2[-1]), ('Elastic-Net', 'positive Elastic-Net'),
           loc='lower left')
plt.axis('tight')
plt.show()
# Out:
# Computing regularization path using the lasso...
# Computing regularization path using the positive lasso...
# Computing regularization path using the elastic net...
# Computing regularization path using the positive elastic net...

# %% [markdown]
# ---
#
# Visit [www.add-for.com](<http://www.add-for.com/IT>) for more tutorials and updates.
#
# This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
