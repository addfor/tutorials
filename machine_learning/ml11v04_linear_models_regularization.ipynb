# %% [markdown]
# # Linear Models Regularization

# %%
import addutils.toc ; addutils.toc.js(ipy_notebook=True)
# Out:
# <div id='toc-container'><script type='text/javascript'>
# $(function() {
#     function regenTOC(){
#         element = $("#toc-container");
#
# 	var toc = document.createElement("div");
# 	$(toc).attr("class", "table-of-contents");
#
# 	var curLevel = 0;
# 	var containerStack = [toc];
# 	var levelOfTag = {"h2": 1, "h3": 2, "h4": 3, "h5": 4};
#
# 	function pushLevel() {
#             var list = document.createElement("ul");
#             containerStack.push(list);
#             curLevel++;
# 	}
#
# 	function popLevel() {
#             var lastContainer = containerStack.pop();
#             $(lastContainer).appendTo(containerStack[containerStack.length - 1]);
#             curLevel--;
# 	}
#
# 	$(".text_cell_render :header").each(function (i, elem) {
#             var level = levelOfTag[ elem.tagName.toLowerCase() ];
#
#             if (level === undefined)
# 		return;
#
#             while (curLevel < level)
# 		pushLevel();
#             while (curLevel > level)
# 		popLevel();
#
#             var listItem = document.createElement("li");
#             var link = document.createElement("a");
#             $(link)
# 		.text($(elem).contents().first().text()) // Remove the pilcrow sign
# 		.attr("href", "#" + $(elem).attr("id"))
# 		.appendTo(listItem);
#             $(listItem).appendTo(containerStack[containerStack.length - 1]);
# 	});
#
# 	while (curLevel > 0)
#             popLevel();
#
#         $("<a class='btn-update' href='#'>Update</a>")
#           .click(regenTOC).prependTo(toc);
#
# 	$(toc).prepend("<div class='title'>Contents</div>")
#           .wrap("<div class='toc-headings'/>");
#
#         $(element).empty();
#         $(element).append(toc);
#     }
#
#     if (typeof(IPython) !== 'undefined')
#         $([IPython.events]).on('notebook_loaded.Notebook', regenTOC);
#     regenTOC();
# });
#
# </script></div>

# %%
import numpy as np
import pandas as pd
from addutils import css_notebook
from sklearn.datasets.samples_generator import make_regression
from sklearn import linear_model
from sklearn import metrics
css_notebook()
# Out:
# <style>
# .text_cell_render @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# div.cell {
#     width: 900px;
#     margin-left: 0% !important;
#     margin-right: 0%;
# }
#
# code {
#     font-size:10pt;
# }
#
# .text_cell_render  h1 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:28pt;
# }
# .text_cell_render h2 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:24pt;
# }
# .text_cell_render h3 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:20pt;
# }
# .text_cell_render h4 {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:18pt;
#     margin-top:12px;
#     margin-bottom: 3px;
# }
#
# .text_cell_render h5 {
#     font-weight: 300;
#     font-size: 11pt;
#     color: rgb( 48, 48, 48 );
#     font-style: italic;
#     margin-bottom: .5em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render ul {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
#     line-height: 185%;
# }
#
# .text_cell_render yp {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 90, 90, 90 );
#     font-size:11pt;
# }
#
# .text_cell_render strong {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 30, 30, 30 );
#     font-size:11pt;
# }
#
# .text_cell_render a:link {
#     font-family: Tahoma, sans-serif;
#     color: rgb( 10, 88, 126 );
#     font-size:11pt;
# }
#
# .text_cell_render a:visited {
#     color:rgb( 10, 88, 126 );
# }
#
# .text_cell_render {
#     font-family: Helvetica, Courier, Computer Modern, "Helvetica Neue", Arial, Geneva, sans-serif;
#     color: rgb( 84, 84, 84 );
#     font-size:11pt;
#     line-height: 125%;
#     font-size: 100%;
#     width:800px;
# }
#
# .CodeMirror {
#     font-family: Courier, "Source Code Pro", source-code-pro,Consolas, monospace;
# }
#
# .warning {
#     color: rgb( 240, 20, 20 );
# }
#
# /* Pandas tables */
# /*
# .rendered_html td {
#     text-align: right;
# }
# */
#
# table.dataframe td {
#     text-align: right;
# }
#
# .output .table-of-contents {
#     border: 1px #cecece solid;
#     background-color: #fafafa;
#     padding-top: 10px;
#     padding-bottom: 5px;
#     padding-right: 15px;
#     padding-left: 0px;
#     margin-bottom: 20px;
#     display: inline-block;
#     position: relative;
# }
#
# .output .table-of-contents ul {
#     list-style-type: none;
#     padding-left: 20px;
# }
#
# .output .table-of-contents .title {
#     font-weight: bold;
#     font-height: 11pt;
#     padding-left: 20px; /* looks better if it's the same to the <ul> */
# }
#
# .output .table-of-contents .btn-update {
#     position: absolute;
#     float: right;
#     right: 11px;
#     top: 4px;
#     font-size: 9pt;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import bokeh.plotting as bk
from bokeh import palettes
from bokeh.layouts import gridplot
bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d7b4d1f-4f46-4bee-b817-9e2ba6722053">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# ## 1.1 Going beyond linearity

# %% [markdown]
# I have simulated a sine curve (between 60° and 300°) and added some random noise using the following code:

# %%
x = np.array([i*np.pi/180 for i in range(60,300,4)])
np.random.seed(10)  #Setting seed for reproducability
y = np.sin(x) + np.random.normal(0,0.15,len(x))
data = pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])
fig = bk.figure(plot_width=630, plot_height=300, title=None)
fig.circle(data['x'], data['y'],)
bk.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2f3559ab-ae55-4782-9a72-f6b3aa250a62"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2f3559ab-ae55-4782-9a72-f6b3aa250a62").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f3559ab-ae55-4782-9a72-f6b3aa250a62");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f3559ab-ae55-4782-9a72-f6b3aa250a62' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"970c0fde-0214-4218-b2bc-688c98e94941":{"roots":{"references":[{"attributes":{"below":[{"id":"9cb311e9-1bf6-428d-9afc-a54e9b4812ad","type":"LinearAxis"}],"left":[{"id":"4649e951-d86c-4808-bcab-736452d53eaa","type":"LinearAxis"}],"plot_height":300,"plot_width":630,"renderers":[{"id":"9cb311e9-1bf6-428d-9afc-a54e9b4812ad","type":"LinearAxis"},{"id":"6159c510-8aaa-4fe9-9d10-f1a2c6008a06","type":"Grid"},{"id":"4649e951-d86c-4808-bcab-736452d53eaa","type":"LinearAxis"},{"id":"e6de8757-791e-4379-9dee-10c39e06d828","type":"Grid"},{"id":"b3f90cd5-f69c-4d88-b8f6-46028027d2b2","type":"BoxAnnotation"},{"id":"103be1b2-cbf6-4934-be88-f87096dca9bf","type":"GlyphRenderer"}],"title":null,"tool_events":{"id":"e7da5e29-4abc-45f5-be16-922b7dd878e1","type":"ToolEvents"},"toolbar":{"id":"ea5095da-ff07-48c5-80b5-5715dc5ec804","type":"Toolbar"},"x_range":{"id":"f4a93e92-5685-43bc-af3f-7b971939ec01","type":"DataRange1d"},"y_range":{"id":"018caa23-6b33-4761-96e4-af6f329386ca","type":"DataRange1d"}},"id":"45b5d6cc-9c72-4f7c-ab32-4ac9fc05207a","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5df3f342-0964-4a91-9603-faba31b43fc3","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6bf54506-c402-4bb0-a9a3-30709161b9f0","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cfd614ca-69c5-4c16-bc34-be0fb3c35758","type":"PanTool"},{"id":"97453a65-1dcf-4ec6-907b-13f35afb95cc","type":"WheelZoomTool"},{"id":"f3111627-c1b6-486f-972a-103ce845e606","type":"BoxZoomTool"},{"id":"bf402c69-ce40-4662-96f6-6231c03f189e","type":"SaveTool"},{"id":"74a1ebd1-df95-4658-adf4-47f21eca7da4","type":"ResetTool"},{"id":"19f01054-e6e8-4cf5-9e9b-feb3dab3d457","type":"HelpTool"}]},"id":"ea5095da-ff07-48c5-80b5-5715dc5ec804","type":"Toolbar"},{"attributes":{"callback":null},"id":"f4a93e92-5685-43bc-af3f-7b971939ec01","type":"DataRange1d"},{"attributes":{},"id":"e7da5e29-4abc-45f5-be16-922b7dd878e1","type":"ToolEvents"},{"attributes":{},"id":"a635087b-3086-4a3a-9ebe-bc2a9bf2af0c","type":"BasicTicker"},{"attributes":{"callback":null},"id":"018caa23-6b33-4761-96e4-af6f329386ca","type":"DataRange1d"},{"attributes":{"formatter":{"id":"5473439f-9834-4616-a3d0-6567f6fd8e39","type":"BasicTickFormatter"},"plot":{"id":"45b5d6cc-9c72-4f7c-ab32-4ac9fc05207a","subtype":"Figure","type":"Plot"},"ticker":{"id":"a635087b-3086-4a3a-9ebe-bc2a9bf2af0c","type":"BasicTicker"}},"id":"9cb311e9-1bf6-428d-9afc-a54e9b4812ad","type":"LinearAxis"},{"attributes":{"formatter":{"id":"61c01f54-d740-49fe-a654-ce1fc72ce3b1","type":"BasicTickFormatter"},"plot":{"id":"45b5d6cc-9c72-4f7c-ab32-4ac9fc05207a","subtype":"Figure","type":"Plot"},"ticker":{"id":"71a36003-3f55-4bd1-8423-59976ca0c12a","type":"BasicTicker"}},"id":"4649e951-d86c-4808-bcab-736452d53eaa","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[60]},"y":{"__ndarray__":"...","dtype":"float64","shape":[60]}}},"id":"233bf526-70dd-495d-bd48-3fba599ec32c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"45b5d6cc-9c72-4f7c-ab32-4ac9fc05207a","subtype":"Figure","type":"Plot"}},"id":"bf402c69-ce40-4662-96f6-6231c03f189e","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"45b5d6cc-9c72-4f7c-ab32-4ac9fc05207a","subtype":"Figure","type":"Plot"},"ticker":{"id":"71a36003-3f55-4bd1-8423-59976ca0c12a","type":"BasicTicker"}},"id":"e6de8757-791e-4379-9dee-10c39e06d828","type":"Grid"},{"attributes":{},"id":"71a36003-3f55-4bd1-8423-59976ca0c12a","type":"BasicTicker"},{"attributes":{"overlay":{"id":"b3f90cd5-f69c-4d88-b8f6-46028027d2b2","type":"BoxAnnotation"},"plot":{"id":"45b5d6cc-9c72-4f7c-ab32-4ac9fc05207a","subtype":"Figure","type":"Plot"} ...

# %% [markdown]
# This resembles a sine curve but not exactly because of the noise. We’ll use this as an example to test different scenarios in this article. Lets try to estimate the sine function using polynomial regression with powers of x form 1 to 15. Lets add a column for each power upto 15 in our dataframe. This can be accomplished using the following code:

# %%
for i in range(2,16):  #power of 1 is already there
    data['x_{}'.format(i)] = data['x']**i
print(data.head())
# Out:
#           x         y       x_2       x_3       x_4       x_5       x_6  \
# 0  1.047198  1.065763  1.096623  1.148381  1.202581  1.259340  1.318778
# 1  1.117011  1.006086  1.247713  1.393709  1.556788  1.738948  1.942424
# 2  1.186824  0.695374  1.408551  1.671702  1.984016  2.354677  2.794587
# 3  1.256637  0.949799  1.579137  1.984402  2.493673  3.133642  3.937850
# 4  1.326450  1.063496  1.759470  2.333850  3.095735  4.106339  5.446854
#
#         x_7       x_8        x_9       x_10       x_11       x_12       x_13  \
# 0  1.381021  1.446202   1.514459   1.585938   1.660790   1.739176   1.821260
# 1  2.169709  2.423588   2.707173   3.023942   3.377775   3.773011   4.214494
# 2  3.316683  3.936319   4.671717   5.544505   6.580351   7.809718   9.268760
# 3  4.948448  6.218404   7.814277   9.819710  12.339811  15.506664  19.486248
# 4  7.224981  9.583578  12.712139  16.862020  22.366630  29.668222  39.353420
#
#         x_14       x_15
# 0   1.907219   1.997235
# 1   4.707635   5.258479
# 2  11.000386  13.055521
# 3  24.487142  30.771450
# 4  52.200353  69.241170

# %%
def linear_power_model(model, data, power):
    #initialize predictors:
    predictors=['x']
    if power >= 2:
        predictors += ['x_{}'.format(i) for i in range(2,power+1)]
    
    #Fit the model
    model.fit(data[predictors],data['y'])
    y_pred = model.predict(data[predictors])
 
    #Return the result in pre-defined format
    rss = sum((y_pred-data['y'])**2)
    ret = [rss]
    ret.extend([model.intercept_])
    ret.extend(model.coef_)
    return ret, y_pred

# %%
results = {}
regr = linear_model.LinearRegression(normalize=True)
for i in range(1,16):
    results[i] = linear_power_model(regr, data, i)

# %%
grid = []
for m in [1, 3, 6, 9, 12, 15]:
    p = bk.figure(plot_width=230, plot_height=300, title='Plot for power {}'.format(m))
    p.circle(data['x'], data['y'],)
    p.line(data['x'], results[m][1], color='firebrick')
    grid.append(p)
bk.show(gridplot(grid, ncols=3))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3a46922a-ed3e-47e5-b44a-bebdbd143d8b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3a46922a-ed3e-47e5-b44a-bebdbd143d8b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3a46922a-ed3e-47e5-b44a-bebdbd143d8b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3a46922a-ed3e-47e5-b44a-bebdbd143d8b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0e184e1d-3de8-43b6-9127-c9ac253e38e7":{"roots":{"references":[{"attributes":{"plot":{"id":"e7f36a95-3a2a-414a-84ee-0166d8ee14be","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed0ba857-9c56-46fb-8221-71245d7713fc","type":"BasicTicker"}},"id":"a374a213-b0ac-4391-8766-26be522ef750","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"28c1c822-5a0d-4a4c-870a-f1325131c74a","type":"PanTool"},{"id":"20d7b7f7-b19a-4368-bddc-f55a1354f81e","type":"WheelZoomTool"},{"id":"07ae4551-a06d-4e0e-a09a-03a43cf798aa","type":"BoxZoomTool"},{"id":"d67bdd1e-bc43-4db2-b47d-db070dc1b6cf","type":"SaveTool"},{"id":"a214651e-89ea-449c-848f-45616f8e4068","type":"ResetTool"},{"id":"7c11dc82-e897-42f3-bd46-2591fe3ba8c9","type":"HelpTool"}]},"id":"0efab3b5-c7a3-4242-89f1-74e5d08cb150","type":"Toolbar"},{"attributes":{"plot":{"id":"a93fc113-295b-4d90-b2b9-67fa93057c24","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f72b515-ecc7-4b0d-a3cf-4a5c64e05f1b","type":"BasicTicker"}},"id":"4ede0ca2-c91e-44cc-acba-a937d4a130c3","type":"Grid"},{"attributes":{"formatter":{"id":"348fc3f2-afe0-483a-9b16-f582f4b60890","type":"BasicTickFormatter"},"plot":{"id":"e7f36a95-3a2a-414a-84ee-0166d8ee14be","subtype":"Figure","type":"Plot"},"ticker":{"id":"fb0569d5-833d-4d42-904b-8d4299f90d98","type":"BasicTicker"}},"id":"d01fcd20-0544-461a-bcb9-64a18e91fad0","type":"LinearAxis"},{"attributes":{"formatter":{"id":"88827c1d-a975-4260-a647-249c4b23db52","type":"BasicTickFormatter"},"plot":{"id":"e7f36a95-3a2a-414a-84ee-0166d8ee14be","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed0ba857-9c56-46fb-8221-71245d7713fc","type":"BasicTicker"}},"id":"d57727de-f95d-4a71-a474-9adadeb780a8","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"e7f36a95-3a2a-414a-84ee-0166d8ee14be","subtype":"Figure","type":"Plot"},"ticker":{"id":"fb0569d5-833d-4d42-904b-8d4299f90d98","type":"BasicTicker"}},"id":"7aeceea8-78f1-4e2a-9cbe-47105c3f6e3b","type":"Grid"},{"attributes":{"callback":null},"id":"d4f034f8-0b7a-4819-b836-95e79ba95ecc","type":"DataRange1d"},{"attributes":{"data_source":{"id":"5a1a557f-402d-4ebc-b2ce-0dbb34dcebf3","type":"ColumnDataSource"},"glyph":{"id":"ddc39866-920f-472d-b319-c98f4b667f55","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"11a582c6-913e-433b-ae09-55bce5b8aeb2","type":"Circle"},"selection_glyph":null},"id":"c65c815e-8f79-406e-9fd5-8261dda47407","type":"GlyphRenderer"},{"attributes":{},"id":"fb0569d5-833d-4d42-904b-8d4299f90d98","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[60]},"y":{"__ndarray__":"...","dtype":"float64","shape":[60]}}},"id":"9b8163fb-24d7-4d76-9f3a-b41424ccb3ce","type":"ColumnDataSource"},{"attributes":{},"id":"bbefbde4-181f-4925-9164-b1595e6eb3f7","type":"ToolEvents"},{"attributes":{"below":[{"id":"d57727de-f95d-4a71-a474-9adadeb780a8","type":"LinearAxis"}],"left":[{"id":"d01fcd20-0544-461a-bcb9-64a18e91fad0","type":"LinearAxis"}],"plot_height":300,"plot_width":230,"renderers":[{"id":"d57727de-f95d-4a71-a474-9adadeb780a8","type":"LinearAxis"},{"id":"a374a213-b0ac-4391-8766-26be522ef750","type":"Grid"},{"id":"d01fcd20-0544-461a-bcb9-64a18e91fad0","type":"LinearAxis"},{"id":"7aeceea8-78f1-4e2a-9cbe-47105c3f6e3b","type":"Grid"},{"id":"5a4d5e57-0bbf-402a-9584-be4fa34e271f","type":"BoxAnnotation"},{"id":"c65c815e-8f79-406e-9fd5-8261dda47407","type":"GlyphRenderer"},{"id":"1f2c2ee3-61f9-4a13-b28c-874c49b631db","type":"GlyphRenderer"}],"title":{"id":"e3346469-1afe-46a0-9672-8fbdacc60d1f","type":"Title"},"tool_events":{"id":"bbefbde4-181f-4925-9164-b1595e6eb3f7","type":"ToolEvents"},"toolbar":{"id":"0efab3b5-c7a3-4242-89f1-74e5d08cb150","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"03cf91da-b99c-4fb9-85e4-3f51e65b5f5b","type":"DataRange1d"},"y_range":{"id":"d4f034f8-0b7a-4819-b836-95e79ba95ecc","type":"DataRange1d"}},"id":"e7f36a95-3a2a-414a-84 ...

# %%
col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['model_pow_%d'%i for i in range(1,16)]
coef_matrix_simple = pd.DataFrame(index=ind, columns=col)
for i in range(1,16):
    coef_matrix_simple.iloc[i-1,0:i+2] = results[i][0]

# %%
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_simple
# Out:
#               rss intercept coef_x_1 coef_x_2 coef_x_3 coef_x_4 coef_x_5  \
# model_pow_1   3.3         2    -0.62      NaN      NaN      NaN      NaN
# model_pow_2   3.3       1.9    -0.58   -0.006      NaN      NaN      NaN
# model_pow_3   1.1      -1.1        3     -1.3     0.14      NaN      NaN
# model_pow_4   1.1     -0.27      1.7    -0.53   -0.036    0.014      NaN
# model_pow_5     1         3     -5.1      4.7     -1.9     0.33   -0.021
# model_pow_6  0.99      -2.8      9.5     -9.7      5.2     -1.6     0.23
# model_pow_7  0.93        19      -56       69      -45       17     -3.5
# model_pow_8  0.92        43 -1.4e+02  1.8e+02 -1.3e+02       58      -15
# model_pow_9  0.87   1.7e+02 -6.1e+02  9.6e+02 -8.5e+02  4.6e+02 -1.6e+02
# model_pow_10 0.87   1.4e+02 -4.9e+02  7.3e+02   -6e+02  2.9e+02      -87
# model_pow_11 0.87       -75  5.1e+02 -1.3e+03  1.9e+03 -1.6e+03  9.1e+02
# model_pow_12 0.87  -3.4e+02  1.9e+03 -4.4e+03    6e+03 -5.2e+03  3.1e+03
# model_pow_13 0.86   3.2e+03 -1.8e+04  4.5e+04 -6.7e+04  6.6e+04 -4.6e+04
# model_pow_14 0.79   2.4e+04 -1.4e+05  3.8e+05 -6.1e+05  6.6e+05   -5e+05
# model_pow_15  0.7  -3.6e+04  2.4e+05 -7.5e+05  1.4e+06 -1.7e+06  1.5e+06
#
#              coef_x_6 coef_x_7 coef_x_8 coef_x_9 coef_x_10 coef_x_11  \
# model_pow_1       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_2       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_3       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_4       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_5       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_6    -0.014      NaN      NaN      NaN       NaN       NaN
# model_pow_7       0.4   -0.019      NaN      NaN       NaN       NaN
# model_pow_8       2.4    -0.21   0.0077      NaN       NaN       NaN
# model_pow_9        37     -5.2     0.42   -0.015       NaN       NaN
# model_pow_10       15    -0.81    -0.14    0.026   -0.0013       NaN
# model_pow_11 -3.5e+02       91      -16      1.8     -0.12    0.0034
# model_pow_12 -1.3e+03  3.8e+02      -80       12      -1.1     0.062
# model_pow_13  2.3e+04 -8.5e+03  2.3e+03 -4.5e+02        62      -5.7
# model_pow_14  2.8e+05 -1.2e+05  3.7e+04 -8.5e+03   1.5e+03  -1.8e+02
# model_pow_15   -1e+06    5e+05 -1.9e+05  5.4e+04  -1.2e+04   1.9e+03
#
#              coef_x_12 coef_x_13 coef_x_14 coef_x_15
# model_pow_1        NaN       NaN       NaN       NaN
# model_pow_2        NaN       NaN       NaN       NaN
# model_pow_3        NaN       NaN       NaN       NaN
# model_pow_4        NaN       NaN       NaN       NaN
# model_pow_5        NaN       NaN       NaN       NaN
# model_pow_6        NaN       NaN       NaN       NaN
# model_pow_7        NaN       NaN       NaN       NaN
# model_pow_8        NaN       NaN       NaN       NaN
# model_pow_9        NaN       NaN       NaN       NaN
# model_pow_10       NaN       NaN       NaN       NaN
# model_pow_11       NaN       NaN       NaN       NaN
# model_pow_12   -0.0016       NaN       NaN       NaN
# model_pow_13      0.31   -0.0078       NaN       NaN
# model_pow_14        15     -0.73     0.017       NaN
# model_pow_15  -2.2e+02        17     -0.81     0.018

# %% [markdown]
# It is clearly evident that the size of coefficients increase exponentially with increase in model complexity. I hope this gives some intuition into why putting a constraint on the magnitude of coefficients can be a good idea to reduce model complexity.
#
# Lets try to understand this even better.
#
# What does a large coefficient signify? It means that we’re putting a lot of emphasis on that feature, i.e. the particular feature is a good predictor for the outcome. When it becomes too large, the algorithm starts modelling intricate relations to estimate the output and ends up overfitting to the particular training data.

# %% [markdown]
# ## 2 Ridge Regression

# %% [markdown]
# Linear Regression rely on the independence of the model terms. When terms are correlated and the columns of the design matrix $X$; have an approximate linear dependence, the matrix $(X^TX)^{-1}$ becomes
# close to singular. As a result, the least-squares estimate becomes highly sensitive to random errors in the observed response *y*, producing a large variance. This situation of multicollinearity can arise, for example, when data are collected without an experimental design.
#
# The ridge coefficients minimize a penalized residual sum of squares:
#
# $$ \underset{w}{min} \|Xw -y\|_2^2 + \alpha \|w\|_2^2$$
#
# Here, positive $\alpha  \geq 0 \hspace{2 pt}$ is a complexity parameter that controls the amount of shrinkage: the larger the value of $\alpha$, the greater the amount of shrinkage and thus the coefficients become more robust to collinearity.
#
# One thing is for sure that any non-zero value would give values less than that of simple linear regression. By how much? We’ll find out soon. Lets see ridge regression in action on the same problem as above.

# %%
alpha_ridge = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]
results = {}
for alpha in alpha_ridge:
    ridgereg = linear_model.Ridge(alpha=alpha,normalize=True)
    results[alpha] = linear_power_model(ridgereg, data, 15)

# %%
grid = []
for m in [1e-15, 1e-10, 1e-3, 1e-2, 1, 5]:
    p = bk.figure(plot_width=230, plot_height=300, title='Plot for alpha {}'.format(m))
    p.circle(data['x'], data['y'],)
    p.line(data['x'], results[m][1], color='firebrick')
    grid.append(p)
bk.show(gridplot(grid, ncols=3))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aa97b130-d1b9-4ed6-8200-b2434dc48321"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("aa97b130-d1b9-4ed6-8200-b2434dc48321").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aa97b130-d1b9-4ed6-8200-b2434dc48321");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aa97b130-d1b9-4ed6-8200-b2434dc48321' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"90cd33c4-da52-4729-af51-264f08a0ca76":{"roots":{"references":[{"attributes":{},"id":"5183ab95-38ec-4cf7-9315-9d05b07eae28","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae7a14fb-339f-43ee-ac1a-a1c877f08976","type":"Line"},{"attributes":{"data_source":{"id":"9fdd534c-eb95-4f77-9183-4d687a3fa144","type":"ColumnDataSource"},"glyph":{"id":"5e216699-f05a-432f-afa7-96d1cef7888c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ae7a14fb-339f-43ee-ac1a-a1c877f08976","type":"Line"},"selection_glyph":null},"id":"2c8a5495-1b26-4aeb-9829-c16d8464f057","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"eb7d5535-e73b-40bf-9010-58a623d4d1a7","type":"LinearAxis"}],"left":[{"id":"8b21fd69-6740-49d7-bfbb-1da0993ee50d","type":"LinearAxis"}],"plot_height":300,"plot_width":230,"renderers":[{"id":"eb7d5535-e73b-40bf-9010-58a623d4d1a7","type":"LinearAxis"},{"id":"676bab9f-5763-4fc1-a432-955c6a03e229","type":"Grid"},{"id":"8b21fd69-6740-49d7-bfbb-1da0993ee50d","type":"LinearAxis"},{"id":"71e9908a-264e-426e-9777-fec550639c18","type":"Grid"},{"id":"7eee6a15-baa3-433a-8bc2-511415cb1e31","type":"BoxAnnotation"},{"id":"30e22da6-95ea-43bf-b934-a3819aac8379","type":"GlyphRenderer"},{"id":"67bf5c32-94b6-48c5-9aac-db339977d0bd","type":"GlyphRenderer"}],"title":{"id":"8d31c448-43eb-445f-8d9c-b446821cae45","type":"Title"},"tool_events":{"id":"e2bf542c-85c0-4a46-b658-ba2bc188d6b0","type":"ToolEvents"},"toolbar":{"id":"2497ba0e-baf4-4f06-aaf6-8fe01e5a71c3","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"06ced801-b880-413c-b2f3-a1d7a697b0d4","type":"DataRange1d"},"y_range":{"id":"b4214694-57be-4312-9e91-6cbc3774ed5a","type":"DataRange1d"}},"id":"070a0b60-86a6-4377-82e7-bbbeb07e88e3","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1334de34-1fe6-4a6d-8cf4-9fa848c15ba7","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"firebrick"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e216699-f05a-432f-afa7-96d1cef7888c","type":"Line"},{"attributes":{"formatter":{"id":"5183ab95-38ec-4cf7-9315-9d05b07eae28","type":"BasicTickFormatter"},"plot":{"id":"c7e26e71-6312-4f67-ba31-386311dba452","subtype":"Figure","type":"Plot"},"ticker":{"id":"0d1ca083-a42b-40d7-ab11-2a97eb413555","type":"BasicTicker"}},"id":"10535ea4-54b5-4e50-b007-19db236d73b6","type":"LinearAxis"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"ece4033c-7c90-4891-a2f2-91bae803e1e9","type":"PanTool"},{"id":"d863bcb1-1403-4754-9e4d-1487a98d5e03","type":"WheelZoomTool"},{"id":"afa9af05-727a-4a1c-adfb-c66e32429d8a","type":"BoxZoomTool"},{"id":"5323380e-1d5f-431d-93a8-1b2c1ca56451","type":"SaveTool"},{"id":"b8f574b6-1cc2-46ee-bfb6-d926c48ef342","type":"ResetTool"},{"id":"273e26ba-5f62-4248-b64e-64bc34bbcda6","type":"HelpTool"},{"id":"ec210403-7734-4f9e-87f1-b3515e84c194","type":"PanTool"},{"id":"f711867f-d6ba-4705-944c-f79b8a80ea32","type":"WheelZoomTool"},{"id":"c541a47b-4f98-4e43-84fd-6776038beed9","type":"BoxZoomTool"},{"id":"4dcc0329-1918-432c-a1d0-e1d3f5b758ba","type":"SaveTool"},{"id":"513c8b49-d170-4de2-8d68-7637033eb15f","type":"ResetTool"},{"id":"73271cb8-b0a1-4531-b2f6-f9cfc0ca41d1","type":"HelpTool"},{"id":"bfc5b6d6-be00-4a42-8f9e-7716a9d3b7ba","type":"PanTool"},{"id":"30596813-d64d-4d3e-a36d-75b3bf670fd5","type":"WheelZoomTool"},{"id":"a87f0023-f665-4660-986e-6a92d25094c6","type":"BoxZoomTool"},{"id":"48deb1c5-e2ed-4078-b076-562e3cecc3f1","type":"SaveTool"},{"id":"202f5790-f17f-467f-b338-0f461fb0473e","type":"ResetTool"},{"id":"42135eaa-471a-4669-8e41-ea6078c47ba7","type":"HelpTool"},{"id":"0b88f9ef-c0ec-4d67-aa37-7584257eb445","type":"PanTool"},{"id":"f1f75476-70bb-452b-b3fa-a2f065489005","type":"WheelZoomTool"},{"id":"6310ed85-8533-48dd-93b6-b11c3a6961cc","type":"BoxZoomTool"},{"id":"16b85333-5a25-49ad-a8f4-3daf0e092755","type":"SaveTool"},{"id":"4fb535f0-5973-4cfb-91cd-c8a97aea70d3","type ...

# %%
col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['alpha_%.2g'%alpha_ridge[i] for i in range(0,10)]
coef_matrix_ridge = pd.DataFrame(index=ind, columns=col)

for i,e in enumerate(alpha_ridge):
    coef_matrix_ridge.iloc[i,] = results[e][0]

# %%
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_simple
# Out:
#               rss intercept coef_x_1 coef_x_2 coef_x_3 coef_x_4 coef_x_5  \
# model_pow_1   3.3         2    -0.62      NaN      NaN      NaN      NaN
# model_pow_2   3.3       1.9    -0.58   -0.006      NaN      NaN      NaN
# model_pow_3   1.1      -1.1        3     -1.3     0.14      NaN      NaN
# model_pow_4   1.1     -0.27      1.7    -0.53   -0.036    0.014      NaN
# model_pow_5     1         3     -5.1      4.7     -1.9     0.33   -0.021
# model_pow_6  0.99      -2.8      9.5     -9.7      5.2     -1.6     0.23
# model_pow_7  0.93        19      -56       69      -45       17     -3.5
# model_pow_8  0.92        43 -1.4e+02  1.8e+02 -1.3e+02       58      -15
# model_pow_9  0.87   1.7e+02 -6.1e+02  9.6e+02 -8.5e+02  4.6e+02 -1.6e+02
# model_pow_10 0.87   1.4e+02 -4.9e+02  7.3e+02   -6e+02  2.9e+02      -87
# model_pow_11 0.87       -75  5.1e+02 -1.3e+03  1.9e+03 -1.6e+03  9.1e+02
# model_pow_12 0.87  -3.4e+02  1.9e+03 -4.4e+03    6e+03 -5.2e+03  3.1e+03
# model_pow_13 0.86   3.2e+03 -1.8e+04  4.5e+04 -6.7e+04  6.6e+04 -4.6e+04
# model_pow_14 0.79   2.4e+04 -1.4e+05  3.8e+05 -6.1e+05  6.6e+05   -5e+05
# model_pow_15  0.7  -3.6e+04  2.4e+05 -7.5e+05  1.4e+06 -1.7e+06  1.5e+06
#
#              coef_x_6 coef_x_7 coef_x_8 coef_x_9 coef_x_10 coef_x_11  \
# model_pow_1       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_2       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_3       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_4       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_5       NaN      NaN      NaN      NaN       NaN       NaN
# model_pow_6    -0.014      NaN      NaN      NaN       NaN       NaN
# model_pow_7       0.4   -0.019      NaN      NaN       NaN       NaN
# model_pow_8       2.4    -0.21   0.0077      NaN       NaN       NaN
# model_pow_9        37     -5.2     0.42   -0.015       NaN       NaN
# model_pow_10       15    -0.81    -0.14    0.026   -0.0013       NaN
# model_pow_11 -3.5e+02       91      -16      1.8     -0.12    0.0034
# model_pow_12 -1.3e+03  3.8e+02      -80       12      -1.1     0.062
# model_pow_13  2.3e+04 -8.5e+03  2.3e+03 -4.5e+02        62      -5.7
# model_pow_14  2.8e+05 -1.2e+05  3.7e+04 -8.5e+03   1.5e+03  -1.8e+02
# model_pow_15   -1e+06    5e+05 -1.9e+05  5.4e+04  -1.2e+04   1.9e+03
#
#              coef_x_12 coef_x_13 coef_x_14 coef_x_15
# model_pow_1        NaN       NaN       NaN       NaN
# model_pow_2        NaN       NaN       NaN       NaN
# model_pow_3        NaN       NaN       NaN       NaN
# model_pow_4        NaN       NaN       NaN       NaN
# model_pow_5        NaN       NaN       NaN       NaN
# model_pow_6        NaN       NaN       NaN       NaN
# model_pow_7        NaN       NaN       NaN       NaN
# model_pow_8        NaN       NaN       NaN       NaN
# model_pow_9        NaN       NaN       NaN       NaN
# model_pow_10       NaN       NaN       NaN       NaN
# model_pow_11       NaN       NaN       NaN       NaN
# model_pow_12   -0.0016       NaN       NaN       NaN
# model_pow_13      0.31   -0.0078       NaN       NaN
# model_pow_14        15     -0.73     0.017       NaN
# model_pow_15  -2.2e+02        17     -0.81     0.018

# %% [markdown]
# This straight away gives us the following inferences:
#
# * The RSS increases with increase in alpha, this model complexity reduces
# * An alpha as small as 1e-15 gives us significant reduction in magnitude of coefficients. How? Compare the coefficients in the first row of this table to the last row of simple linear regression table.
# * High alpha values can lead to significant underfitting. Note the rapid increase in RSS for values of alpha greater than 1
# * Though the coefficients are very very small, they are NOT zero.
#
# The first 3 are very intuitive. But #4 is also a crucial observation. Let’s reconfirm the same by determining the number of zeros in each row of the coefficients data set:

# %%
coef_matrix_ridge.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha_1e-15     0
# alpha_1e-10     0
# alpha_1e-08     0
# alpha_0.0001    0
# alpha_0.001     0
# alpha_0.01      0
# alpha_1         0
# alpha_5         0
# alpha_10        0
# alpha_20        0
# dtype: int64

# %% [markdown]
# This confirms that all the 15 coefficients are greater than zero in magnitude (can be +ve or -ve). Remember this observation and have a look again until its clear. This will play an important role in later while comparing ridge with lasso regression.

# %% [markdown]
# ## 3 LASSO

# %% [markdown]
# The Lasso is a linear model that estimates sparse coefficients. It is useful in some contexts due to its tendency to prefer solutions with fewer parameter values, effectively reducing the number of variables upon which the given solution is dependent. For this reason, the Lasso and its variants are fundamental to the field of compressed sensing. Under certain conditions, it can recover the exact set of non-zero weights.
#
# Mathematically, it consists of a linear model trained with $\ell_1$ prior as regularizer. The objective function to minimize is:
#
# $$\underset{w}{min\,} { \frac{1}{2n_{samples}} ||X w - y||_2 ^ 2 + \alpha ||w||_1}$$
#
# The lasso estimate thus solves the minimization of the least-squares penalty with $\alpha$ $||w||_1$ added, where $\alpha$ is a constant and $||w||_1$ is the $\ell_1$-norm of the parameter vector.

# %%
alpha_lasso = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]
results = {}
for alpha in alpha_lasso:
    lassoreg = linear_model.Lasso(alpha=alpha, normalize=True)
    results[alpha] = linear_power_model(lassoreg, data, 15)
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
grid = []
for m in [1e-15, 1e-10, 1e-3, 1e-4, 1e-2, 1]:
    p = bk.figure(plot_width=230, plot_height=300, title='Plot for alpha {}'.format(m))
    p.circle(data['x'], data['y'],)
    p.line(data['x'], results[m][1], color='firebrick')
    grid.append(p)
bk.show(gridplot(grid, ncols=3))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="80e49614-28ab-4db0-a2b7-e40a46911170"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("80e49614-28ab-4db0-a2b7-e40a46911170").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80e49614-28ab-4db0-a2b7-e40a46911170");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80e49614-28ab-4db0-a2b7-e40a46911170' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"396134cd-c947-494f-958b-e5913bb0d39d":{"roots":{"references":[{"attributes":{"plot":{"id":"6d2b06cb-800e-4f2d-b2dc-63fafda56ccb","subtype":"Figure","type":"Plot"}},"id":"93be0788-6f17-4997-8022-490e043948f2","type":"ResetTool"},{"attributes":{"plot":{"id":"6d2b06cb-800e-4f2d-b2dc-63fafda56ccb","subtype":"Figure","type":"Plot"}},"id":"457575fa-e6a9-4ea5-a02c-e59396014e4d","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f8c17859-b530-425d-bf59-f064200f0609","type":"BoxAnnotation"},{"attributes":{},"id":"4e50f69a-28fa-49af-ad79-50089cd1be8d","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7632944-f6c7-421d-9e7e-05ccea130fb9","type":"Line"},{"attributes":{"plot":{"id":"6c52354e-53fd-45fb-9768-2c757eeeef7a","subtype":"Figure","type":"Plot"}},"id":"59f9b275-2d01-474a-aa61-26454774a66e","type":"PanTool"},{"attributes":{},"id":"60d3fae4-9dfb-4d11-aa64-71c6f2606324","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Plot for alpha 0.0001"},"id":"642e1478-c636-462a-ba29-46d11cc15ac4","type":"Title"},{"attributes":{"overlay":{"id":"fac5cda8-d446-4226-8c8b-d06d3568a35a","type":"BoxAnnotation"},"plot":{"id":"6c52354e-53fd-45fb-9768-2c757eeeef7a","subtype":"Figure","type":"Plot"}},"id":"9170f905-a4f8-4f96-ae89-8d7ddd4345d2","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"04bd0d1e-0261-4584-85fc-83e1b022400e","type":"LinearAxis"}],"left":[{"id":"b59fe71c-038f-4e86-b46d-5f0167bd0c36","type":"LinearAxis"}],"plot_height":300,"plot_width":230,"renderers":[{"id":"04bd0d1e-0261-4584-85fc-83e1b022400e","type":"LinearAxis"},{"id":"bf7adea3-8e8e-4a0c-b678-eebf5e0862d7","type":"Grid"},{"id":"b59fe71c-038f-4e86-b46d-5f0167bd0c36","type":"LinearAxis"},{"id":"95e6522d-bf90-4312-86d6-f5079e83ed3e","type":"Grid"},{"id":"4cc8e5c5-0c4d-4cf2-b267-6769f89a0fd6","type":"BoxAnnotation"},{"id":"d9f70913-f940-4e88-aa6a-789048993591","type":"GlyphRenderer"},{"id":"a1541abe-81f3-47d4-8cd7-689aee2e49d2","type":"GlyphRenderer"}],"title":{"id":"642e1478-c636-462a-ba29-46d11cc15ac4","type":"Title"},"tool_events":{"id":"4ad64d67-423f-4a10-bec8-1737b3703e3b","type":"ToolEvents"},"toolbar":{"id":"d04e632f-d630-4524-9d5b-256680d1086e","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"b794b8a1-6698-44ce-afca-9a46f98f1582","type":"DataRange1d"},"y_range":{"id":"835233cc-1c17-433a-9490-b22fe125e30a","type":"DataRange1d"}},"id":"05b41044-aebc-42fa-b4b4-04cbe76bf9ee","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"firebrick"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce3957a7-58f3-43de-9bbd-6fa4e9066bc1","type":"Line"},{"attributes":{"plot":{"id":"6c52354e-53fd-45fb-9768-2c757eeeef7a","subtype":"Figure","type":"Plot"}},"id":"29389dfb-0fab-461b-b48f-dd9bf15edcaa","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"bdb53eb4-e946-4ba3-b56b-b06fa25636b0","type":"LinearAxis"}],"left":[{"id":"300425cc-32a9-469e-aaa8-ae539ac5bef5","type":"LinearAxis"}],"plot_height":300,"plot_width":230,"renderers":[{"id":"bdb53eb4-e946-4ba3-b56b-b06fa25636b0","type":"LinearAxis"},{"id":"57890a89-72b2-4741-ab1a-ed67f11c66ac","type":"Grid"},{"id":"300425cc-32a9-469e-aaa8-ae539ac5bef5","type":"LinearAxis"},{"id":"7235b9d9-8c36-4fe9-b8b0-8ece3d996420","type":"Grid"},{"id":"f8c17859-b530-425d-bf59-f064200f0609","type":"BoxAnnotation"},{"id":"2114c398-33b4-4017-a634-63c2f6124b04","type":"GlyphRenderer"},{"id":"57ff7c81-6fcc-4b8e-a387-a3a679ca16d7","type":"GlyphRenderer"}],"title":{"id":"94064ec6-e3e3-415f-bc1e-7e529bac5185","type":"Title"},"tool_events":{"id":"98dcda3c-e1dd-4191-99a8-05f400eac8eb","type":"ToolEvents"},"toolbar":{"id":" ...

# %% [markdown]
# This again tells us that the model complexity decreases with increase in the values of alpha. But notice the straight line at alpha=1. Appears a bit strange to me. Let’s explore this further by looking at the coefficients:

# %%
col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['alpha_%.2g'%alpha_lasso[i] for i in range(0,10)]
coef_matrix_lasso = pd.DataFrame(index=ind, columns=col)

for i,e in enumerate(alpha_lasso):
    coef_matrix_lasso.iloc[i,] = results[e][0]

# %%
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_lasso
# Out:
#               rss intercept coef_x_1 coef_x_2 coef_x_3 coef_x_4 coef_x_5  \
# alpha_1e-15  0.97      0.14      1.1     -0.3   -0.024 -0.00052   0.0003
# alpha_1e-10  0.97      0.14      1.1     -0.3   -0.024 -0.00052   0.0003
# alpha_1e-08  0.97      0.14      1.1     -0.3   -0.024 -0.00052   0.0003
# alpha_0.0001    1      0.61      0.6    -0.19   -0.022       -0       -0
# alpha_0.001   1.7       1.3       -0    -0.13       -0       -0       -0
# alpha_0.01    3.6       1.8    -0.55 -0.00056       -0       -0       -0
# alpha_1        37     0.038       -0       -0       -0       -0       -0
# alpha_5        37     0.038       -0       -0       -0       -0       -0
# alpha_10       37     0.038       -0       -0       -0       -0       -0
# alpha_20       37     0.038       -0       -0       -0       -0       -0
#
#              coef_x_6 coef_x_7 coef_x_8 coef_x_9 coef_x_10 coef_x_11  \
# alpha_1e-15   8.8e-05  1.7e-05  2.9e-06  4.1e-07   4.7e-08   2.9e-09
# alpha_1e-10   8.8e-05  1.7e-05  2.9e-06  4.1e-07   4.7e-08   2.9e-09
# alpha_1e-08   8.8e-05  1.7e-05  2.9e-06  4.1e-07   4.7e-08   2.9e-09
# alpha_0.0001  1.1e-05  2.4e-05  3.2e-06  3.2e-07   4.4e-09         0
# alpha_0.001         0        0        0        0         0   1.5e-08
# alpha_0.01         -0       -0       -0       -0         0         0
# alpha_1            -0       -0       -0       -0        -0        -0
# alpha_5            -0       -0       -0       -0        -0        -0
# alpha_10           -0       -0       -0       -0        -0        -0
# alpha_20           -0       -0       -0       -0        -0        -0
#
#              coef_x_12 coef_x_13 coef_x_14 coef_x_15
# alpha_1e-15   -5.3e-10    -3e-10    -9e-11  -2.3e-11
# alpha_1e-10   -5.3e-10    -3e-10    -9e-11  -2.3e-11
# alpha_1e-08   -5.3e-10    -3e-10    -9e-11  -2.3e-11
# alpha_0.0001         0        -0        -0  -2.9e-11
# alpha_0.001    7.5e-10         0         0         0
# alpha_0.01           0         0         0         0
# alpha_1             -0        -0        -0        -0
# alpha_5             -0        -0        -0        -0
# alpha_10            -0        -0        -0        -0
# alpha_20            -0        -0        -0        -0

# %% [markdown]
# Apart from the expected inference of higher RSS for higher alphas, we can see the following:
#
# * For the same values of alpha, the coefficients of lasso regression are much smaller as compared to that of ridge regression (compare row 1 of the 2 tables).
# * For the same alpha, lasso has higher RSS (poorer fit) as compared to ridge regression
# * Many of the coefficients are zero even for very small values of alpha
#
# Inferences #1,2 might not generalize always but will hold for many cases. The real difference from ridge is coming out in the last inference. Lets check the number of coefficients which are zero in each model using following code:

# %%
coef_matrix_lasso.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha_1e-15      0
# alpha_1e-10      0
# alpha_1e-08      0
# alpha_0.0001     6
# alpha_0.001     12
# alpha_0.01      13
# alpha_1         15
# alpha_5         15
# alpha_10        15
# alpha_20        15
# dtype: int64

# %% [markdown]
# We can observe that even for a small value of alpha, a significant number of coefficients are zero. This also explains the horizontal line fit for alpha=1 in the lasso plots, its just a baseline model! This phenomenon of most of the coefficients being zero is called "sparsity". Lasso can perform feature selection, especially where sparsity in data is a correct assumption, for example for problems where $p >> n$ such as micro array data.

# %% [markdown]
# ## 4 Remarks
#
# 1. Key Difference
#
#     * Ridge: It includes all (or none) of the features in the model. Thus, the major advantage of ridge regression is coefficient shrinkage and reducing model complexity.
#     * Lasso: Along with shrinking coefficients, lasso performs feature selection as well. (Remember the ‘selection‘ in the lasso full-form?) As we observed earlier, some of the coefficients become exactly zero, which is equivalent to the particular feature being excluded from the model.
#
# 2. Typical Use Cases
#
#     * Ridge: It is majorly used to prevent overfitting. Since it includes all the features, it is not very useful in case of exorbitantly high #features, say in millions, as it will pose computational challenges.
#     * Lasso: Since it provides sparse solutions, it is generally the model of choice (or some variant of this concept) for modelling cases where the #features are in millions or more. In such a case, getting a sparse solution is of great computational advantage as the features with zero coefficients can simply be ignored.
#
# 3. Presence of Highly Correlated Features
#
#     * Ridge: It generally works well even in presence of highly correlated features as it will include all of them in the model but the coefficients will be distributed among them depending on the correlation.
#     * Lasso: It arbitrarily selects any one feature among the highly correlated ones and reduced the coefficients of the rest to zero. Also, the chosen variable changes randomly with change in model parameters. This generally doesn’t work that well as compared to ridge regression.
#
# Along with Ridge and Lasso, **Elastic Net** is another useful techniques which combines both L1 and L2 regularization. It can be used to balance out the pros and cons of ridge and lasso regression. I encourage you to explore it further.

# %% [markdown]
# ---
#
# Visit [www.add-for.com](<http://www.add-for.com/IT>) for more tutorials and updates.
#
# This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
