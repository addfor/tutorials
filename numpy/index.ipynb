# %% [markdown]
# * [__Numpy Basic Concepts__](np01v01_numpy_basics.ipynb)
#     * [1 What is Numpy ?](np01v01_numpy_basics.ipynb#1-What-is-Numpy-?)
#         * [1.1 Documentation and reference:](np01v01_numpy_basics.ipynb#1.1-Documentation-and-reference:)
#     * [2 Array Creation](np01v01_numpy_basics.ipynb#2-Array-Creation)
#         * [2.1 Array creation functions](np01v01_numpy_basics.ipynb#2.1-Array-creation-functions)
#         * [2.2 Sequences and reshaping](np01v01_numpy_basics.ipynb#2.2-Sequences-and-reshaping)
#         * [2.3 Sparse Matrices](np01v01_numpy_basics.ipynb#2.3-Sparse-Matrices)
#         * [2.4 Random Numbers](np01v01_numpy_basics.ipynb#2.4-Random-Numbers)
#         * [2.5 Casting](np01v01_numpy_basics.ipynb#2.5-Casting)
#     * [3 Basic Visualization with matplotlib](np01v01_numpy_basics.ipynb#3-Basic-Visualization-with-matplotlib)
#         * [3.1 D Plotting](np01v01_numpy_basics.ipynb#3.1-D-Plotting)
#     * [4 Basic Linear Algebra](np01v01_numpy_basics.ipynb#4-Basic-Linear-Algebra)
#         * [4.1 Determinant of a square matrix](np01v01_numpy_basics.ipynb#4.1-Determinant-of-a-square-matrix)
#         * [4.2 Inverse of a square matrix](np01v01_numpy_basics.ipynb#4.2-Inverse-of-a-square-matrix)
#         * [4.3 Advanced Linear Algebra](np01v01_numpy_basics.ipynb#4.3-Advanced-Linear-Algebra)
#     * [5 Slicing -Indexing for MATLAB<sup>&reg;</sup> Users-](np01v01_numpy_basics.ipynb#5-Slicing--Indexing-for-MATLAB<sup>&reg;</sup>-Users-)
#         * [5.1 Indexing single elements](np01v01_numpy_basics.ipynb#5.1-Indexing-single-elements)
#         * [5.2 Indexing by rows and columns](np01v01_numpy_basics.ipynb#5.2-Indexing-by-rows-and-columns)
#     * [6 File Input / Output](np01v01_numpy_basics.ipynb#6-File-Input-/-Output)
# * [__PyTables__](np02v01_numpy_PyTables.ipynb)
#     * [1 The Array Object](np02v01_numpy_PyTables.ipynb#1-The-Array-Object)
#     * [2 The CArray Object](np02v01_numpy_PyTables.ipynb#2-The-CArray-Object)
#     * [3 The Table Object](np02v01_numpy_PyTables.ipynb#3-The-Table-Object)
#     * [4 The EArray Object](np02v01_numpy_PyTables.ipynb#4-The-EArray-Object)
# * [__Numpy - Plotting with Matplotlib__](np03v01_numpy_plotting.ipynb)
#     * [1 Simple 2D Plots](np03v01_numpy_plotting.ipynb#1-Simple-2D-Plots)
#     * [2 Subplots](np03v01_numpy_plotting.ipynb#2-Subplots)
#     * [3 Axes](np03v01_numpy_plotting.ipynb#3-Axes)
#     * [4 Example: Cycle Trough many colors](np03v01_numpy_plotting.ipynb#4-Example:-Cycle-Trough-many-colors)
#     * [5 Example: Filled Plots](np03v01_numpy_plotting.ipynb#5-Example:-Filled-Plots)
#     * [6 Example: Custom Scatter Plot](np03v01_numpy_plotting.ipynb#6-Example:-Custom-Scatter-Plot)
#     * [7 Example: Custom Histogram](np03v01_numpy_plotting.ipynb#7-Example:-Custom-Histogram)
#     * [8 Example: Simple 3D Plot - Surface](np03v01_numpy_plotting.ipynb#8-Example:-Simple-3D-Plot---Surface)
#     * [9 Example: Colormaps](np03v01_numpy_plotting.ipynb#9-Example:-Colormaps)
#     * [10 Example: Skew and Kurtosis](np03v01_numpy_plotting.ipynb#10-Example:-Skew-and-Kurtosis)
# * [__Scipy - Optimization__](np04v01_scipy_optimization.ipynb)
#     * [1 Brief Introduction to Optimization](np04v01_scipy_optimization.ipynb#1-Brief-Introduction-to-Optimization)
#         * [1.1 Dimensionality of the problem](np04v01_scipy_optimization.ipynb#1.1-Dimensionality-of-the-problem)
#         * [1.2 Convex versus non-convex optimization](np04v01_scipy_optimization.ipynb#1.2-Convex-versus-non-convex-optimization)
#         * [1.3 Smooth and non-smooth problems](np04v01_scipy_optimization.ipynb#1.3-Smooth-and-non-smooth-problems)
#     * [2 A Simpe Optimization Example](np04v01_scipy_optimization.ipynb#2-A-Simpe-Optimization-Example)
#     * [3 Finding the roots of a scalar function](np04v01_scipy_optimization.ipynb#3-Finding-the-roots-of-a-scalar-function)
#     * [4 Curve Fitting](np04v01_scipy_optimization.ipynb#4-Curve-Fitting)
#     * [5 Optimizing with Box-Bound Constraints](np04v01_scipy_optimization.ipynb#5-Optimizing-with-Box-Bound-Constraints)
# * [__1 Scipy Signal Processing: IIR Filter Design__](np05v01_scipy_sig_processing_IIRfilter_design.ipynb)
#     * [1 Filter Specification](np05v01_scipy_sig_processing_IIRfilter_design.ipynb#1-Filter-Specification)
#     * [2 Filter Design](np05v01_scipy_sig_processing_IIRfilter_design.ipynb#2-Filter-Design)
#     * [3 Frequency and Phase Response](np05v01_scipy_sig_processing_IIRfilter_design.ipynb#3-Frequency-and-Phase-Response)
#     * [4 Step and Impulse Response](np05v01_scipy_sig_processing_IIRfilter_design.ipynb#4-Step-and-Impulse-Response)
# * [__Symbolic Computation__](np06v01_Symbolic_Computation.ipynb)
#     * [1 Basic manipulation](np06v01_Symbolic_Computation.ipynb#1-Basic-manipulation)
#     * [2 Solve](np06v01_Symbolic_Computation.ipynb#2-Solve)
#     * [3 Algebra](np06v01_Symbolic_Computation.ipynb#3-Algebra)
#         * [3.1 Expand and Factor](np06v01_Symbolic_Computation.ipynb#3.1-Expand-and-Factor)
#         * [3.2 Symplify](np06v01_Symbolic_Computation.ipynb#3.2-Symplify)
#         * [3.3 apart and together](np06v01_Symbolic_Computation.ipynb#3.3-apart-and-together)
#     * [4 Calculus](np06v01_Symbolic_Computation.ipynb#4-Calculus)
#         * [4.1 Differentiation and Integration](np06v01_Symbolic_Computation.ipynb#4.1-Differentiation-and-Integration)
#         * [4.2 Sum and Products](np06v01_Symbolic_Computation.ipynb#4.2-Sum-and-Products)
#         * [4.3 Limits](np06v01_Symbolic_Computation.ipynb#4.3-Limits)
#         * [4.4 Series](np06v01_Symbolic_Computation.ipynb#4.4-Series)
#     * [5 Linear algebra](np06v01_Symbolic_Computation.ipynb#5-Linear-algebra)
#         * [5.1 Matrices](np06v01_Symbolic_Computation.ipynb#5.1-Matrices)
#     * [6 Solving Equations](np06v01_Symbolic_Computation.ipynb#6-Solving-Equations)
