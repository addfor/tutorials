# %% [markdown]
# # Python Style Guide

# %% [markdown]
# * [1 PEP8](#1-PEP8)
# * [2 Syntax and Naming Conventions](#2-Syntax-and-Naming-Conventions)
#     * [2.1 Avoid using semicolons at the end of lines](#2.1-Avoid-using-semicolons-at-the-end-of-lines)
#     * [2.2 Avoid having multiple statements on a single line](#2.2-Avoid-having-multiple-statements-on-a-single-line)
#     * [2.3 Indent your code block with 4 spaces](#2.3-Indent-your-code-block-with-4-spaces)
#     * [2.4 Imports: Should always be on separate lines, if refered to different modules.](#2.4-Imports:-Should-always-be-on-separate-lines,-if-refered-to-different-modules.)
#     * [2.5 Whitespace: required or not?](#2.5-Whitespace:-required-or-not?)
#     * [2.6 Naming: names in python should be chosen according to the following conventions:](#2.6-Naming:-names-in-python-should-be-chosen-according-to-the-following-conventions:)
# * [3 Working with Data](#3-Working-with-Data)
#     * [3.1 Avoid using a temporary variable when swapping two variables](#3.1-Avoid-using-a-temporary-variable-when-swapping-two-variables)
#     * [3.2 Use tuples to unpack data](#3.2-Use-tuples-to-unpack-data)
#     * [3.3 Strings: Use join and list to create a string from a list and viceversa](#3.3-Strings:-Use-join-and-list-to-create-a-string-from-a-list-and-viceversa)
#     * [3.4 Strings: Use startswith and endswith instead of string slicing to check for prefixes or suffixes.](#3.4-Strings:-Use-startswith-and-endswith-instead-of-string-slicing-to-check-for-prefixes-or-suffixes.)
#     * [3.5 Dictionaries: Use the default parameter of dict.get to provide default values](#3.5-Dictionaries:-Use-the-default-parameter-of-dict.get-to-provide-default-values)
#     * [3.6 File IO: Use Context Managers to ensure resources are properly managed](#3.6-File-IO:-Use-Context-Managers-to-ensure-resources-are-properly-managed)
# * [4 Control Structures](#4-Control-Structures)
#     * [4.1 Don't compare boolean values to True or False using ==](#4.1-Don't-compare-boolean-values-to-True-or-False-using-==)
#     * [4.2 Avoid placing conditional branch on the same line as the colon](#4.2-Avoid-placing-conditional-branch-on-the-same-line-as-the-colon)
#     * [4.3 Comparisons to singletons like None should always be done with is or is not.](#4.3-Comparisons-to-singletons-like-None-should-always-be-done-with-is-or-is-not.)
#     * [4.4 Avoid repeating variable name in compound if Statement](#4.4-Avoid-repeating-variable-name-in-compound-if-Statement)
#     * [4.5 Use list comprehensions to create lists that are subsets of existing data](#4.5-Use-list-comprehensions-to-create-lists-that-are-subsets-of-existing-data)
#     * [4.6 Indexes in for Loops](#4.6-Indexes-in-for-Loops)
#     * [4.7 range` and `xrange`](#4.7-range`-and-`xrange`)

# %% [markdown]
# You will soon realize that the Python community often cite the *Pythonic approach to do things*.
#
# *'Pythonic'* refers to the principles laid out in *'The Zen of Python'*: a collection of basic coding rules to allow Python code to be more readable, maintainable and accessible to both novice and experienced developers. You can access *'The Zen of Python'* by typing at any time `import this` in any Python interpreter.

# %%
from addutils import css_notebook
css_notebook()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:900px;
#         margin-left:0% !important;
#         margin-right:0%;
#     }
#
# 	code{
# 		font-size:10pt
# 	}
#
#     h1 {
#         font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:28pt;
#     }
# 	h2 {
#         font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:24pt;
#     }
# 	h3 {
#         font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:20pt;
#     }
#     h4 {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:18pt;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#
# 	ul {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 90, 90, 90 );
# 		font-size:11pt;
# 		line-height: 185%;
# 		}
#
# 	p {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 90, 90, 90 );
# 		font-size:11pt;
# 		}
#
# 	strong {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 30, 30, 30 );
# 		font-size:11pt;
# 		}
#
# 	a:link {
# 		font-family: Tahoma, sans-serif;
# 		color: rgb( 10, 88, 126 );
# 		font-size:11pt;
# 		}
#
# 	a:visited {
# 		color:rgb( 10, 88, 126 );
# 	}
#
#     div.text_cell_render{
#         font-family: Helvetica, Courier, Computer Modern, "Helvetica Neue", Arial, Geneva, sans-serif;
# 		color: rgb( 84, 84, 84 );
# 		font-size:11pt;
#         line-height: 125%;
#         font-size: 100%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: Courier, "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 11pt;
#         color: rgb( 48, 48, 48 );
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# .rendered_html td
# {
# text-align: right;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Basically in Python you can do almost anything. Adopting the following rules will help you to avoid code like this (to see the result run the cell and then open the file M.bmp that will be generated in this folder):

# %%
_                                      =   (
                                        255,
                                      lambda
                               V       ,B,c
                             :c   and Y(V*V+B,B,  c
                               -1)if(abs(V)<6)else
               (              2+c-4*abs(V)**-0.4)/i
                 )  ;v,      x=320,240;C=range(v*x
                  );import  struct;P=struct.pack;M,\
            j  ='<QIIHHHH',open('M.bmp','wb').write
for X in j('BM'+P(M,v*x*3+26,26,12,v,x,1,24))or C:
            i  ,Y=_;j(P('BBB',*(lambda T:(T*80+T**9
                  *i-950*T  **99,T*70-880*T**18+701*
                 T  **9     ,T*i**(1-T**45*2)))(sum(
               [              Y(0,(A%3/3.+X%v+(X/v+
                               A/3/3.-x/2)/1j)*2.5
                             /x   -2.7,i)**2 for  \
                               A       in C
                                      [:9]])
                                        /9)
                                       )   )

# %% [markdown]
# ## 1 PEP8

# %% [markdown]
# PEP is an acronym for  Python Enhancement Proposals. The whole list can be found [HERE](http://www.python.org/dev/peps/).
#
# [PEP8](http://www.python.org/dev/peps/pep-0008/) in particular contains coding convections and is perhaps the most explicit example of idioms within the Python community. In Computer Science, idioms are preferred ways of writing code (often there are many possible coding solutions to reach the same results, and some solutions are considered better than others, both for readability and performance reasons). We highly recommend to read PEP8 before start your career as a Python Programmer.
# It will be higly recommendable to use a PEP8 style-checking plugin to be shure your code is fully compliant with that rules.

# %% [markdown]
# ## 2 Syntax and Naming Conventions

# %% [markdown]
# ### 2.1 Avoid using semicolons at the end of lines

# %% [markdown]
# Even if allowed, python doesn't need it!

# %%
# WRONG
var = 15;
s = "I like semicolons";
a = 1; b =2; c = 3

# %%
# CORRECT
var = 15
s = "No semicolons!"
a, b, c = 1, 2, 3

# %% [markdown]
# ### 2.2 Avoid having multiple statements on a single line

# %% [markdown]
#         # WRONG
#         if condition: a = 1; b =2; c = 3
#
#         # CORRECT
#         if condition:
#             a, b, c = 1, 2, 3

# %% [markdown]
# ### 2.3 Indent your code block with 4 spaces

# %% [markdown]
# Never use tabs or mix tabs and spaces. In cases of implied line continuation, you should align wrapped elements either vertically, as for the examples in the line length section; or using a hanging indent of 4 spaces, in which case there should be no argument on the first line.
#
#         # WRONG - Stuff on first line forbidden
#         lfunc = long_function_name(var_one, var_two,
#             var_three, var_four)
#
#         # CORRECT - Aligned with opening delimiter
#         lfunc = long_function_name(var_one, var_two,
#                                    var_three, var_four)

# %% [markdown]
#         # WRONG 2-space hanging indent forbidden
#         lfunc = long_function_name(
#           var_one, var_two, var_three,
#           var_four)
#
#         # CORRECT 4-space hanging indent; nothing on first line
#         lfunc = long_function_name(
#             var_one, var_two, var_three,
#             var_four)

# %% [markdown]
# ### 2.4 Imports: Should always be on separate lines, if refered to different modules.

# %% [markdown]
# Always on top of modules. Avoid **from module import *** if not strictly required.
# Imports should be grouped in the following order:
#
# * standard library imports
# * related third party imports
# * local application/library specific imports

# %%
# WRONG 
import sys, os
from math import *

# %%
# CORRECT
import sys
import os
from math import gamma

# %% [markdown]
# ### 2.5 Whitespace: required or not?

# %% [markdown]
# No spaces in parentheses.
#
#         # WRONG
#         spam( ham[ 1 ], { eggs: 2 }, [ ] )
#
#         #CORRECT
#         spam(ham[1], {eggs: 2}, [])

# %% [markdown]
# No whitespace before a comma, semicolon, or colon. Do use whitespace after a comma, semicolon, or colon except at the end of the line.

# %%
import random
y = 2
x = random.randint(1, 5)

# WRONG
if x == 4 :
    print x , y
x , y = y , x
# Out:
# 4 2

# %%
# CORRECT
if x == 4:
    print x, y
x, y = y, x

# %% [markdown]
# No whitespace before the open paren/bracket that starts an argument list, indexing or slicing.
#
#         # WRONG
#         spam (1)
#         dict ['key'] = list [index]
#
#         # CORRECT
#         spam(1)
#         dict['key'] = list[index]

# %% [markdown]
# Don't use spaces around the **=** operator when used to indicate a keyword argument or a default parameter value.

# %%
# WRONG
def complex(real, imag = 0.0):
    return magic(r = real, i = imag)

# %%
# CORRECT
def complex(real, imag=0.0):
    return magic(r=real, i=imag)

# %% [markdown]
# Surround binary operators with a single space on either side for assignment (**=**), comparisons (**==**, **<**, **>**, **!=**, **<>**, **<=**, **>=**, **in**, **not in**, **is**, **is not**), and Booleans (**and**, **or**, **not**). Use your better judgment for the insertion of spaces around arithmetic operators but always be consistent about whitespace on either side of a binary operator.
# ```python
#         # WRONG
#         x<1
#
#
#         # CORRECT
#         x == 1
# ```

# %% [markdown]
# Don't use spaces to vertically align tokens on consecutive lines, since it becomes a maintenance burden (applies to **:**, **#**, **=**, etc.):

# %%
# WRONG
short     = 1000  # comment
long_name = 2     # comment that should not be aligned

dictionary = {
   'foo'      : 1,
   'long_name': 2,
}

# %%
# CORRECT
short = 1000  # comment
long_name = 2  # comment that should not be aligned

dictionary = {
    'foo': 1,
    'long_name': 2,
}

# %% [markdown]
# ### 2.6 Naming: names in python should be chosen according to the following conventions:

# %% [markdown]
# * object naming:
# `module_name, package_name, ClassName, method_name, ExceptionName, function_name, GLOBAL_CONSTANT_NAME, global_var_name, instance_var_name, function_parameter_name, local_var_name`.
# * avoid single character names except for counters or iterators
# * avoid dashes (-) in any package/module name
# * `__double_leading_and_trailing_underscore` names (reserved by Python)

# %% [markdown]
# ## 3 Working with Data

# %% [markdown]
# ### 3.1 Avoid using a temporary variable when swapping two variables

# %% [markdown]
# There is no reason to swap using a temporary variable in Python. We can use tuples to make our code more readable

# %%
# WRONG - Swap two variables using a temporary variable
a, b = 10, 20
temp = a
a = b
b = temp

# %%
# CORRECT - Swap two variables using tuples
(a,b) = (b,a) # Parentesis can be omitted

# %% [markdown]
# ### 3.2 Use tuples to unpack data

# %% [markdown]
# In Python, it is possible to 'pack' and 'unpack' data. This is mostly used while passing multiple values to functions.

# %%
# WRONG - Unpack values with single instructions
packed = ['car', 'Cevy', 160] 
vehicle = packed[0]
make = packed[1]
speed = packed[2]

# %%
# CORRECT - Unpack values using tuples
packed = ['car', 'Cevy', 160] 
(vehicle, make, speed) = packed

# %% [markdown]
# ### 3.3 Strings: Use join and list to create a string from a list and viceversa

# %%
mylist = ['u', 's', 'e', ' ', 'j', 'o', 'i', 'n', '(', '', ')']
# WRONG
mystr = ''
for letter in mylist:
    mystr = mystr + letter
    
# CORRECT
mystr = ''.join(mylist)

# CORRECT: generate a list from a string
mylist2 = list('this will be a list')
print mylist2
# Out:
# ['t', 'h', 'i', 's', ' ', 'w', 'i', 'l', 'l', ' ', 'b', 'e', ' ', 'a', ' ', 'l', 'i', 's', 't']

# %% [markdown]
# ### 3.4 Strings: Use startswith and endswith instead of string slicing to check for prefixes or suffixes.

# %%
mystr = 'Check me'
# WRONG
print mystr[:5] == 'Check'

# CORRECT
print mystr.startswith('Check')
# Out:
# True
# True

# %% [markdown]
# ### 3.5 Dictionaries: Use the default parameter of dict.get to provide default values

# %%
# WRONG
power = dict([('on', 100), ('off', 0)])
if 'idle' in power:
    print power['idle']
else:
    print 0.1
# Out:
# 0.1

# %%
# CORRECT
print power.get('idle', 0.1)
# Out:
# 0.1

# %% [markdown]
# ### 3.6 File IO: Use Context Managers to ensure resources are properly managed

# %% [markdown]
#     # WRONG - If the function 'do_something' generates an exception
#     #         the file will never be closed
#     file_handle = open('myfile', 'r')
#     for line in file_handle.readlines():
#         do_something(line):
#     file_handle.close()
#
#     # CORRECT - Using 'with' you don''t need to explicitly call 'close'
#     with open('myfile', 'r') as file_handle:
#         for line in file_handle.readlines():
#             do_something(line):

# %% [markdown]
# ## 4 Control Structures

# %% [markdown]
# ### 4.1 Don't compare boolean values to True or False using ==

# %% [markdown]
#     # WRONG
#     if condition == True:
#     if condition is True:
#
#     # CORRECT
#     if condition:

# %%
# Remember that empty strings, lists or tuples are false
mylist = [1, 2, 3]
if mylist:
    print 'There is something to do!'
# Out:
# There is something to do!

# %% [markdown]
# ### 4.2 Avoid placing conditional branch on the same line as the colon

# %% [markdown]
#     # WRONG
#     if condition: print (something)
#
#     # CORRECT
#     if condition:
#         print (something)

# %% [markdown]
# ### 4.3 Comparisons to singletons like None should always be done with is or is not.

# %%
# WRONG
mytest = None
if mytest == None:
    print 'This is wrong'

# CORRECT
if mytest is None:
    print 'This is correct'
# Out:
# This is wrong
# This is correct

# %% [markdown]
# ### 4.4 Avoid repeating variable name in compound if Statement

# %%
a = 'two'
# WRONG
if a == 'one' or a == 'two' or a == 'three':
    print 'This works but is wrong'

# CORRECT
if a in ('one', 'two', 'three'):
    print 'This is correct!'
# Out:
# This works but is wrong
# This is correct!

# %% [markdown]
# ### 4.5 Use list comprehensions to create lists that are subsets of existing data

# %% [markdown]
# List comprehensions, when used judiciously, increase clarity in code that builds a list from existing data. Moreover list comprehensions can speed-up the code.

# %%
# WRONG
origin = range(1, 100)
mylist = list()
for item in origin:
    if not item%5:
        mylist.append(item+0.1)

# CORRECT
mylist = [item+0.1 for item in origin if not item%5]

# %% [markdown]
# ### 4.6 Indexes in for Loops

# %% [markdown]
# Programmers coming from other languages are used to iterate over a container by accessing elements via index. Python's **in** keyword handles this gracefully.

# %%
mylist = ['a', 'b', 'c', 1, 2, 3]
# WRONG
index = 0
while index < len(mylist):
    print (mylist[index]),
    index+=1
    
# CORRECT
for item in mylist:
    print item,
# Out:
# a b c 1 2 3 a b c 1 2 3

# %%
# CORRECT - When the index is needed for any reason, use 'enumerate'
for index, item in enumerate(mylist):
    print index, item, ' -- ',
# Out:
# 0 a  --  1 b  --  2 c  --  3 1  --  4 2  --  5 3  --

# %% [markdown]
# ### 4.7 range` and `xrange`

# %% [markdown]
# When creating an index for a `for` loop, use `xrange` instead of `range` because range build the full list in memory before starting the loop, instead xrange generates an iterator that provide the new value just when called.

# %%
# WRONG
sum1 = 0
for x in range(1000*1000):
    sum1 = sum1+x

# CORRECT
sum2 = 0
for x in xrange(1000*1000):
    sum2 = sum2+x
    
print 'Sum1: {0} -- Sum2: {1}'.format(sum1, sum2)
# Out:
# Sum1: 499999500000 -- Sum2: 499999500000

# %% [markdown]
# ---
#
# Email **training [at ]add-for [dot] com** for more information and custom training programs.
